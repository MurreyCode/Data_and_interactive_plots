# %%
import os
from google.colab import drive
drive.mount('/gdrive', force_remount=True)

root_dir = '/gdrive/My Drive/datascience/workshops/Data_and_interactive_plots/'
for f in os.listdir(root_dir):
  print(f)
# Out:
# Mounted at /gdrive
# 1.Plot Open Data Files using Dash-EMPTY.ipynb
# requirements.txt
# 3. Searching info using APIs-EMPTY.ipynb
# 1.Plot Open Data Files using Dash.ipynb
# 2. Ploting information in Maps.ipynb
# DadesSabadell
# README.md
# 4. Sabadell Cinema Example.ipynb
# DadesBarcelona
# LICENSE.md
# .git
# .gitignore

# %% [markdown]
# # Open Data Sabadell
#
#
# http://opendata.sabadell.cat/ca/
#
# From main page **Catàleg** we select **Medi Ambient** (Environment) category.
# In there, we can find a file related to municipal waste that can be downloaded from [here.](http://opendata.sabadell.cat/index.php?option=com_iasopendata&view=download&format=raw&urlOData=aHR0cDovL29kYXRhLnNhYmFkZWxsLmNhdC9vZGF0YTRQcm9kdWN0b3Ivb2RhdGE0UHJvZHVjdG9yLnN2Yy9NYXRlcmlhbHNSZXNpZHVzLz9mb3JtYXQ9Y3N2JmlkZGlzdD0xNDYyJiRzZWxlY3Q9T3JkcmUsQW55byxJZE1hdGVyaWFsLE5vbU1hdGVyaWFsLFF1YW50aXRhdCxVbml0YXRz) But you can find a copy of this file named **residus.csv** in this tutorial dataset in **DadesSabadell** folder.
#
# The file obtained is in a CSV format (Comma Separated Value). This means that it is
# like a table where the rows are registers and the columns are fields or values associated to this register.
#
# You can take a look into this file in table-like representation provided in the open data web page following this link: [OpenData Sabadell](http://opendata.sabadell.cat/ca/inici/odata?iddist=1462). Looking this table we can observe that every register represents an amount of waste origined in Sabadell in tones associated with a particular year and a waste type classification.
#
# In this exercice we are going to follow this steps:
# * Read residus.csv file.
# * Group data to obtain more readable information. Every row will be a type of waste and the columns will be a year related to this data.
# * Represent data in an interactive way.
#
# **Important:** Nan values indicate that there is no infomation related to this type of waste and year.

# %% [markdown]
# To read data and manage it we are going to use [pandas](https://pandas.pydata.org/) library:

# %%
import pandas as pd

#df = pd.read_csv(root_dir + "DadesSabadell/residus.csv",sep=';')
df = pd.read_csv("DadesSabadell/residus.csv",sep=';')

df.sort_values(by="Anyo",inplace = True)

df.head()
# Out:
#      Ordre  Anyo  IdMaterial      NomMaterial  Quantitat Unitats
# 339    338  1984          28      Voluminosos        NaN   Tones
# 390    389  1984           2            Paper        NaN   Tones
# 179    179  1984           3          Envasos        NaN   Tones
# 247    246  1984          16            Piles        NaN   Tones
# 234    233  1984           9  Fracció vegetal        NaN   Tones

# %%
materials = list(df.NomMaterial.unique())
materials.remove("Resta")

print ('{} diferent types of wastes:'.format(len(materials)))
materials
# Out:
# 45 diferent types of wastes:
# ['Voluminosos',
#  'Paper',
#  'Envasos',
#  'Piles',
#  'Fracció vegetal',
#  'Vidre',
#  'Tèxtil',
#  'Medicaments i cosmètics',
#  'Olis vegetals',
#  'Ferralla',
#  'Vidre Pla',
#  'Runes',
#  'Fusta',
#  'Sòlids i Pastosos',
#  'Àcids',
#  'Aerosols',
#  'RAEE A1: Aparells de fred, frigorífics...',
#  'Tòners',
#  'Olis minerals',
#  'Dissolvents',
#  'Reactius de laboratori',
#  'Pneumàtics',
#  'RAEE A3: Televisors i monitors',
#  'Comburents',
#  'RAEE A2: Grans electrodomèstics assecadores, rentadores...',
#  'Coure',
#  'Càpsules de cafè',
#  'RAEE A5: làmpares fluorescents',
#  'Bases',
#  'Bateries',
#  'Medicaments',
#  'RAEE A4: Ordinadors, aspiradores, joguines elèctriques i electròniques....',
#  'Altres residus especials',
#  'Materia orgànica',
#  'Radiografies',
#  'Porexpan',
#  'Plàstic rígid',
#  'Cd i DVD',
#  'Cartró',
#  "RAEE FRA 6 (A4) Aparells petits d'informàtica i telecomunicacions ",
#  'RAEE FRA 5 (A4) Petits aparells sense dimensió superior a 50 cm',
#  'RAEE FRA 4 (A2) Altres aparells amb tamany superior a 50 cm no inclosos en FRA 1',
#  'RAEE FRA 3 (A5) Lampares i fluorescents',
#  'RAEE FRA 2 (A3) Monitors i pantalles LED, CRT i altres',
#  "RAEE FRA (A1) Grans aparells d'intercanvi de temperatura, frigotrifics, aire acondicionat..."]

# %%
pd.pivot_table(df,columns="Anyo", index = "NomMaterial", values="Quantitat")
# Out:
# Anyo                                                1984     1985     1986  \
# NomMaterial
# Aerosols                                             NaN      NaN      NaN
# Altres residus especials                             NaN      NaN      NaN
# Bases                                                NaN      NaN      NaN
# Bateries                                             NaN      NaN      NaN
# Cartró                                               NaN      NaN      NaN
# Cd i DVD                                             NaN      NaN      NaN
# Comburents                                           NaN      NaN      NaN
# Coure                                                NaN      NaN      NaN
# Càpsules de cafè                                     NaN      NaN      NaN
# Dissolvents                                          NaN      NaN      NaN
# Envasos                                              NaN      NaN      NaN
# Ferralla                                             NaN      NaN      NaN
# Fracció vegetal                                      NaN      NaN      NaN
# Fusta                                                NaN      NaN      NaN
# Materia orgànica                                     NaN      NaN      NaN
# Medicaments                                          NaN      NaN      NaN
# Medicaments i cosmètics                              NaN      NaN      NaN
# Olis minerals                                        NaN      NaN      NaN
# Olis vegetals                                        NaN      NaN      NaN
# Paper                                                NaN      NaN      NaN
# Piles                                                NaN      NaN      NaN
# Plàstic rígid                                        NaN      NaN      NaN
# Pneumàtics                                           NaN      NaN      NaN
# Porexpan                                             NaN      NaN      NaN
# RAEE A1: Aparells de fred, frigorífics...            NaN      NaN      NaN
# RAEE A2: Grans electrodomèstics assecadores, re...   NaN      NaN      NaN
# RAEE A3: Televisors i monitors                       NaN      NaN      NaN
# RAEE A4: Ordinadors, aspiradores, joguines elèc...   NaN      NaN      NaN
# RAEE A5: làmpares fluorescents                       NaN      NaN      NaN
# RAEE FRA (A1) Grans aparells d'intercanvi de te...   NaN      NaN      NaN
# RAEE FRA 2 (A3) Monitors i pantalles LED, CRT i...   NaN      NaN      NaN
# RAEE FRA 3 (A5) Lampares i fluorescents              NaN      NaN      NaN
# RAEE FRA 4 (A2) Altres aparells amb tamany supe...   NaN      NaN      NaN
# RAEE FRA 5 (A4) Petits aparells sense dimensió ...   NaN      NaN      NaN
# RAEE FRA 6 (A4) Aparells petits d'informàtica i...   NaN      NaN      NaN
# Radiografies                                         NaN      NaN      NaN
# Reactius de laboratori                               NaN      NaN      NaN
# Resta                                                NaN  49485.0  50894.0
# Runes                                                NaN      NaN      NaN
# Sòlids i Pastosos                                    NaN      NaN      NaN
# Tèxtil                                               NaN      NaN      NaN
# Tòners                                               NaN      NaN      NaN
# Vidre                                               46.0    103.0    204.0
# Vidre Pla                                            NaN      NaN      NaN
# Voluminosos                                          NaN      NaN      NaN
# Àcids                                                NaN      NaN      NaN
#
# Anyo                                                   1987     1988   1989  \
# NomMaterial
# Aerosols                                                NaN      NaN    NaN
# Altres residus especials                                NaN      NaN    NaN
# Bases                                                   NaN      NaN    NaN
# Bateries                                                NaN      NaN    NaN
# Cartró                                                  NaN      NaN    NaN
# Cd i DVD                                                NaN      NaN    NaN
# Comburents                                              NaN      NaN    NaN
# Coure                                                   NaN      NaN    NaN
# Càpsules de cafè                                        NaN      NaN    NaN
# Dissolvents                                             NaN      NaN    NaN
# Envasos                                                 NaN      NaN    NaN
# Ferralla                                                NaN      NaN    NaN
# Fracció vegetal                                         NaN      NaN    NaN
# Fusta                                                   NaN      NaN    NaN
# Materia orgànica                                        NaN      NaN    NaN
# Medicaments                                             NaN      NaN    NaN
# Medicaments i cosmètics                                 NaN      NaN    NaN
# Olis minerals                                           NaN      NaN    NaN
# Olis vegetals                                           NaN      NaN    NaN
# Paper                                                   NaN      NaN    NaN
# Piles                                                   NaN      NaN    NaN
# Plàstic rígid                                           NaN      NaN    NaN
# Pneumàtics                                              NaN      NaN    NaN
# Porexpan                                                NaN      NaN    NaN
# RAEE A1: Aparells de fred, frigorífics...               NaN      NaN    NaN
# RAEE A2: Grans electrodomèstics assecadores, re...      NaN      NaN    NaN
# RAEE A3: Televisors i monitors                          NaN      NaN    NaN
# RAEE A4: Ordinadors, aspiradores, joguines elèc...      NaN      NaN    NaN
# RAEE A5: làmpares fluorescents                          NaN      NaN    NaN
# RAEE FRA (A1) Grans aparells d'intercanvi de te...      NaN      NaN    NaN
# RAEE FRA 2 (A3) Monitors i pantalles LED, CRT i...      NaN      NaN    NaN
# RAEE FRA 3 (A5) Lampares i fluorescents                 NaN      NaN    NaN
# RAEE FRA 4 (A2) Altres aparells amb tamany supe...      NaN      NaN    NaN
# RAEE FRA 5 (A4) Petits aparells sense dimensió ...      NaN      NaN    NaN
# RAEE FRA 6 (A4) Aparells petits d'informàtica i...      NaN      NaN    NaN
# Radiografies                                            NaN      NaN    NaN
# Reactius de laboratori                                  NaN      NaN    NaN
# Resta                                               54649.0  57987.0    NaN
# Runes                                                   NaN      NaN    NaN
# Sòlids i Pastosos                                       NaN      NaN    NaN
# Tèxtil                                                  NaN      NaN    NaN
# Tòners                                                  NaN      NaN    NaN
# Vidre                                                 317.0      NaN  373.0
# Vidre Pla                                               NaN      NaN    NaN
# Voluminosos                                             NaN      NaN    NaN
# Àcids                                                   NaN      NaN    NaN
#
# Anyo                                                   1990     1991     1992  \
# NomMaterial
# Aerosols                                                NaN      NaN      NaN
# Altres residus especials                                NaN      NaN      NaN
# Bases                                                   NaN      NaN      NaN
# Bateries                                                NaN      NaN      NaN
# Cartró                                                  NaN      NaN      NaN
# Cd i DVD                                                NaN      NaN      NaN
# Comburents                                              NaN      NaN      NaN
# Coure                                                   NaN      NaN      NaN
# Càpsules de cafè                                        NaN      NaN      NaN
# Dissolvents                                             NaN      NaN      NaN
# Envasos                                                 NaN      NaN      NaN
# Ferralla                                                NaN      NaN      NaN
# Fracció vegetal                                         NaN      NaN      NaN
# Fusta                                                   NaN      NaN      NaN
# Materia orgànica                                        NaN      NaN      NaN
# Medicaments                                             NaN      NaN      NaN
# Medicaments i cosmètics                                 NaN      NaN      NaN
# Olis minerals                                           NaN      NaN      NaN
# Olis vegetals                                           NaN      NaN      NaN
# Paper                                                   NaN      NaN      NaN
# Piles                                                   NaN      NaN      NaN
# Plàstic rígid                                           NaN      NaN      NaN
# Pneumàtics                                              NaN      NaN      NaN
# Porexpan                                                NaN      NaN      NaN
# RAEE A1: Aparells de fred, frigorífics...               NaN      NaN      NaN
# RAEE A2: Grans electrodomèstics assecadores, re...      NaN      NaN      NaN
# RAEE A3: Televisors i monitors                          NaN      NaN      NaN
# RAEE A4: Ordinadors, aspiradores, joguines elèc...      NaN      NaN      NaN
# RAEE A5: làmpares fluorescents                          NaN      NaN      NaN
# RAEE FRA (A1) Grans aparells d'intercanvi de te...      NaN      NaN      NaN
# RAEE FRA 2 (A3) Monitors i pantalles LED, CRT i...      NaN      NaN      NaN
# RAEE FRA 3 (A5) Lampares i fluorescents                 NaN      NaN      NaN
# RAEE FRA 4 (A2) Altres aparells amb tamany supe...      NaN      NaN      NaN
# RAEE FRA 5 (A4) Petits aparells sense dimensió ...      NaN      NaN      NaN
# RAEE FRA 6 (A4) Aparells petits d'informàtica i...      NaN      NaN      NaN
# Radiografies                                            NaN      NaN      NaN
# Reactius de laboratori                                  NaN      NaN      NaN
# Resta                                               63035.0  71728.0  77390.0
# Runes                                                   NaN      NaN      NaN
# Sòlids i Pastosos                                       NaN      NaN      NaN
# Tèxtil                                                  NaN      NaN      NaN
# Tòners                                                  NaN      NaN      NaN
# Vidre                                                 397.0    560.0    735.0
# Vidre Pla                                               NaN      NaN      NaN
# Voluminosos                                             NaN      NaN      NaN
# Àcids                                                   NaN      NaN      NaN
#
# Anyo                                                   1993   ...        2009  \
# NomMaterial                                                   ...
# Aerosols                                                NaN   ...         1.0
# Altres residus especials                                NaN   ...         1.0
# Bases                                                   NaN   ...         0.0
# Bateries                                                NaN   ...        13.0
# Cartró                                                  NaN   ...         NaN
# Cd i DVD                                                NaN   ...         0.0
# Comburents                                              NaN   ...         0.0
# Coure                                                   NaN   ...         1.0
# Càpsules de cafè                                        NaN   ...         3.0
# Dissolvents                                             NaN   ...         7.0
# Envasos                                                 NaN   ...      4244.0
# Ferralla                                                NaN   ...       378.0
# Fracció vegetal                                         NaN   ...       859.0
# Fusta                                                   NaN   ...      2423.0
# Materia orgànica                                        NaN   ...      6799.0
# Medicaments                                             NaN   ...        18.0
# Medicaments i cosmètics                                 NaN   ...         0.0
# Olis minerals                                           NaN   ...        26.0
# Olis vegetals                                           NaN   ...        24.0
# Paper                                                   NaN   ...         NaN
# Piles                                                   NaN   ...        22.0
# Plàstic rígid                                           NaN   ...       126.0
# Pneumàtics                                              NaN   ...        24.0
# Porexpan                                                NaN   ...        24.0
# RAEE A1: Aparells de fred, frigorífics...               NaN   ...        34.0
# RAEE A2: Grans electrodomèstics assecadores, re...      NaN   ...        66.0
# RAEE A3: Televisors i monitors                          NaN   ...         NaN
# RAEE A4: Ordinadors, aspiradores, joguines elèc...      NaN   ...         NaN
# RAEE A5: làmpares fluorescents                          NaN   ...         9.0
# RAEE FRA (A1) Grans aparells d'intercanvi de te...      NaN   ...         NaN
# RAEE FRA 2 (A3) Monitors i pantalles LED, CRT i...      NaN   ...         NaN
# RAEE FRA 3 (A5) Lampares i fluorescents                 NaN   ...         NaN
# RAEE FRA 4 (A2) Altres aparells amb tamany supe...      NaN   ...         NaN
# RAEE FRA 5 (A4) Petits aparells sense dimensió ...      NaN   ...         NaN
# RAEE FRA 6 (A4) Aparells petits d'informàtica i...      NaN   ...         NaN
# Radiografies                                            NaN   ...         NaN
# Reactius de laboratori                                  NaN   ...         2.0
# Resta                                               78710.0   ...     69412.0
# Runes                                                   NaN   ...      2905.0
# Sòlids i Pastosos                                       NaN   ...        58.0
# Tèxtil                                                  NaN   ...       200.0
# Tòners                                                  NaN   ...         0.0
# Vidre                                                   NaN   ...      3266.0
# Vidre Pla                                               NaN   ...       409.0
# Voluminosos                                             NaN   ...         NaN
# Àcids                                                   NaN   ...         NaN
#
# Anyo                                                   2010     2011     2012  \
# NomMaterial
# Aerosols                                                1.0      1.0      0.0
# Altres residus especials                                1.0      1.0      2.0
# Bases                                                   0.0      0.0      0.0
# Bateries                                               12.0      9.0     14.0
# Cartró                                                  NaN     52.0     20.0
# Cd i DVD                                                2.0      NaN      1.0
# Comburents                                              0.0      0.0      0.0
# Coure                                                   1.0      1.0      NaN
# Càpsules de cafè                                        NaN      NaN      NaN
# Dissolvents                                             8.0      NaN      4.0
# Envasos                                              4318.0   4340.0   4057.0
# Ferralla                                                NaN    166.0     98.0
# Fracció vegetal                                      1040.0    345.0    137.0
# Fusta                                                2568.0   2326.0      NaN
# Materia orgànica                                     6896.0   7131.0   6924.0
# Medicaments                                            19.0      NaN      NaN
# Medicaments i cosmètics                                 NaN      0.0      0.0
# Olis minerals                                           NaN     15.0     12.0
# Olis vegetals                                          29.0     28.0     26.0
# Paper                                                9029.0   7091.0   4971.0
# Piles                                                  22.0      9.0     16.0
# Plàstic rígid                                         113.0    102.0     70.0
# Pneumàtics                                              7.0      NaN      NaN
# Porexpan                                                9.0     14.0      1.0
# RAEE A1: Aparells de fred, frigorífics...              69.0     16.0      NaN
# RAEE A2: Grans electrodomèstics assecadores, re...      NaN     40.0     27.0
# RAEE A3: Televisors i monitors                        159.0    107.0     69.0
# RAEE A4: Ordinadors, aspiradores, joguines elèc...     87.0     73.0     57.0
# RAEE A5: làmpares fluorescents                          NaN      6.0      4.0
# RAEE FRA (A1) Grans aparells d'intercanvi de te...      NaN      NaN      NaN
# RAEE FRA 2 (A3) Monitors i pantalles LED, CRT i...      NaN      NaN      NaN
# RAEE FRA 3 (A5) Lampares i fluorescents                 NaN      NaN      NaN
# RAEE FRA 4 (A2) Altres aparells amb tamany supe...      NaN      NaN      NaN
# RAEE FRA 5 (A4) Petits aparells sense dimensió ...      NaN      NaN      NaN
# RAEE FRA 6 (A4) Aparells petits d'informàtica i...      NaN      NaN      NaN
# Radiografies                                            NaN      NaN      1.0
# Reactius de laboratori                                  NaN      2.0      1.0
# Resta                                               67551.0  64594.0  60046.0
# Runes                                                3577.0   4565.0   4556.0
# Sòlids i Pastosos                                      57.0     45.0     20.0
# Tèxtil                                                213.0      NaN    195.0
# Tòners                                                  NaN      NaN      NaN
# Vidre                                                3129.0   3040.0      NaN
# Vidre Pla                                             379.0    332.0    285.0
# Voluminosos                                          4544.0   4496.0   1866.0
# Àcids                                                   0.0      0.0      0.0
#
# Anyo                                                   2013     2014    2015  \
# NomMaterial
# Aerosols                                                NaN      1.0     NaN
# Altres residus especials                               37.0      NaN     NaN
# Bases                                                   NaN      0.0     NaN
# Bateries                                               26.0      NaN     3.0
# Cartró                                                  NaN      NaN     NaN
# Cd i DVD                                                1.0      1.0     NaN
# Comburents                                              NaN      NaN     NaN
# Coure                                                   0.0      0.0     0.0
# Càpsules de cafè                                        NaN      NaN     NaN
# Dissolvents                                             6.0      5.0     NaN
# Envasos                                                 NaN   3999.0  3329.0
# Ferralla                                              111.0    127.0     NaN
# Fracció vegetal                                       400.0      NaN   274.0
# Fusta                                                1876.0    948.0  1233.0
# Materia orgànica                                     7069.0   6596.0     NaN
# Medicaments                                             NaN      NaN     NaN
# Medicaments i cosmètics                                 NaN      3.0     NaN
# Olis minerals                                          10.0      8.0     9.0
# Olis vegetals                                           NaN     34.0    19.0
# Paper                                                4429.0   4340.0  3923.0
# Piles                                                  14.0     15.0     4.0
# Plàstic rígid                                          86.0     45.0    33.0
# Pneumàtics                                             20.0     15.0    15.0
# Porexpan                                                1.0      1.0    10.0
# RAEE A1: Aparells de fred, frigorífics...              12.0     15.0    20.0
# RAEE A2: Grans electrodomèstics assecadores, re...     22.0     23.0    31.0
# RAEE A3: Televisors i monitors                         63.0     56.0    52.0
# RAEE A4: Ordinadors, aspiradores, joguines elèc...     49.0      NaN    47.0
# RAEE A5: làmpares fluorescents                          3.0      7.0     NaN
# RAEE FRA (A1) Grans aparells d'intercanvi de te...      NaN      NaN     NaN
# RAEE FRA 2 (A3) Monitors i pantalles LED, CRT i...      NaN      NaN     NaN
# RAEE FRA 3 (A5) Lampares i fluorescents                 NaN      NaN     NaN
# RAEE FRA 4 (A2) Altres aparells amb tamany supe...      NaN      NaN     NaN
# RAEE FRA 5 (A4) Petits aparells sense dimensió ...      NaN      NaN     NaN
# RAEE FRA 6 (A4) Aparells petits d'informàtica i...      NaN      NaN     NaN
# Radiografies                                            0.0      NaN     0.0
# Reactius de laboratori                                  NaN      0.0     NaN
# Resta                                               56172.0  57009.0     NaN
# Runes                                                   NaN   3229.0  3387.0
# Sòlids i Pastosos                                       NaN     33.0     NaN
# Tèxtil                                                277.0    273.0   344.0
# Tòners                                                  NaN      NaN     NaN
# Vidre                                                3107.0   2956.0  3129.0
# Vidre Pla                                             293.0    276.0   342.0
# Voluminosos                                          1656.0   4160.0  4540.0
# Àcids                                                   NaN      0.0     NaN
#
# Anyo                                                   2016     2017     2018
# NomMaterial
# Aerosols                                                NaN      NaN      NaN
# Altres residus especials                                NaN      6.0      NaN
# Bases                                                   NaN      1.0      NaN
# Bateries                                                3.0      2.0      2.0
# Cartró                                                  NaN      NaN      NaN
# Cd i DVD                                                NaN      1.0      NaN
# Comburents                                              NaN      6.0      NaN
# Coure                                                   1.0      0.0      1.0
# Càpsules de cafè                                        NaN      2.0      NaN
# Dissolvents                                             NaN      9.0      NaN
# Envasos                                              2665.0   2806.0   2576.0
# Ferralla                                              109.0    120.0    158.0
# Fracció vegetal                                       867.0    559.0    112.0
# Fusta                                                1548.0   2279.0   1700.0
# Materia orgànica                                     4897.0   4718.0   4088.0
# Medicaments                                             NaN      NaN      NaN
# Medicaments i cosmètics                                 NaN      1.0      NaN
# Olis minerals                                           8.0      NaN      4.0
# Olis vegetals                                          33.0     31.0     10.0
# Paper                                                   NaN   4097.0   3613.0
# Piles                                                   0.0      6.0      0.0
# Plàstic rígid                                          44.0     43.0     34.0
# Pneumàtics                                              3.0      9.0      NaN
# Porexpan                                                0.0      1.0      1.0
# RAEE A1: Aparells de fred, frigorífics...              26.0      NaN      NaN
# RAEE A2: Grans electrodomèstics assecadores, re...     36.0      NaN      NaN
# RAEE A3: Televisors i monitors                          NaN      NaN      NaN
# RAEE A4: Ordinadors, aspiradores, joguines elèc...     43.0      NaN      NaN
# RAEE A5: làmpares fluorescents                          3.0      NaN      NaN
# RAEE FRA (A1) Grans aparells d'intercanvi de te...      5.0     39.0      NaN
# RAEE FRA 2 (A3) Monitors i pantalles LED, CRT i...     13.0     51.0     28.0
# RAEE FRA 3 (A5) Lampares i fluorescents                 1.0      2.0      2.0
# RAEE FRA 4 (A2) Altres aparells amb tamany supe...      4.0     41.0      NaN
# RAEE FRA 5 (A4) Petits aparells sense dimensió ...      6.0     34.0     18.0
# RAEE FRA 6 (A4) Aparells petits d'informàtica i...      4.0     27.0     16.0
# Radiografies                                            NaN      0.0      NaN
# Reactius de laboratori                                  NaN      0.0      NaN
# Resta                                               61177.0  60747.0  46530.0
# Runes                                                4225.0   4299.0   3268.0
# Sòlids i Pastosos                                       NaN     39.0      NaN
# Tèxtil                                                391.0    408.0      NaN
# Tòners                                                  0.0      4.0      3.0
# Vidre                                                3030.0   3112.0   2775.0
# Vidre Pla                                             322.0    301.0    249.0
# Voluminosos                                             NaN   5606.0   4144.0
# Àcids                                                   NaN      0.0      NaN
#
# [46 rows x 35 columns]

# %% [markdown]
# All is prepared to plot our data. We are going to us Dash (web-based interfaces in Python) to plot information and give them interactivity.
#
# If you are interested to learn more about Dash you can follow the offical [tutorial.](https://dash.plot.ly/)
#
# [Dash installation:](https://dash.plot.ly/installation)
#
# * **pip install dash**  # The core dash backend
# * **pip install dash-html-components**  # HTML components
# * **pip install dash-core-components**  # Supercharged components
# * **pip install dash-table**  # Interactive DataTable component (new!)

# %%
# !pip install dash # The core dash backend
# !pip install dash-html-components # HTML components
# !pip install dash-core-components # Supercharged components
# !pip install dash-table # Interactive DataTable component (new!)
# Out:
# Collecting dash
#   Downloading https://files.pythonhosted.org/packages/d4/f0/4bec0479caab415a67b7f17706b9bce1d1345532bcc5a4b0e3c589ccd79d/dash-0.36.0.tar.gz
# Requirement already satisfied: Flask>=0.12 in /usr/local/lib/python3.6/dist-packages (from dash) (1.0.2)
# Collecting flask-compress (from dash)
#   Downloading https://files.pythonhosted.org/packages/0e/2a/378bd072928f6d92fd8c417d66b00c757dc361c0405a46a0134de6fd323d/Flask-Compress-1.4.0.tar.gz
# Requirement already satisfied: plotly in /usr/local/lib/python3.6/dist-packages (from dash) (1.12.12)
# Collecting dash_renderer (from dash)
#   Downloading https://files.pythonhosted.org/packages/94/f2/70083bfdb19fd278d64980d293e0b8b6a0efedc81a0a41c34544a343c045/dash_renderer-0.17.0.tar.gz (936kB)
#     100% |████████████████████████████████| 942kB 6.9MB/s
# Requirement already satisfied: Jinja2>=2.10 in /usr/local/lib/python3.6/dist-packages (from Flask>=0.12->dash) (2.10)
# Requirement already satisfied: click>=5.1 in /usr/local/lib/python3.6/dist-packages (from Flask>=0.12->dash) (7.0)
# Requirement already satisfied: Werkzeug>=0.14 in /usr/local/lib/python3.6/dist-packages (from Flask>=0.12->dash) (0.14.1)
# Requirement already satisfied: itsdangerous>=0.24 in /usr/local/lib/python3.6/dist-packages (from Flask>=0.12->dash) (1.1.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from plotly->dash) (2.18.4)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from plotly->dash) (1.11.0)
# Requirement already satisfied: pytz in /usr/local/lib/python3.6/dist-packages (from plotly->dash) (2018.9)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.6/dist-packages (from Jinja2>=2.10->Flask>=0.12->dash) (1.1.0)
# Requirement already satisfied: urllib3<1.23,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->plotly->dash) (1.22)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->plotly->dash) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->plotly->dash) (2018.11.29)
# Requirement already satisfied: idna<2.7,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->plotly->dash) (2.6)
# Building wheels for collected packages: dash, flask-compress, dash-renderer
# done
#   Stored in directory: /root/.cache/pip/wheels/fc/e7/af/d0b551efefa68836b2792b86b3105dabac3b44136db3a6827a
# done
#   Stored in directory: /root/.cache/pip/wheels/96/32/88/a1f6d9dd3c29570ab3a8acc0d556b3b20abcf3c623c868ce0a
# done
#   Stored in directory: /root/.cache/pip/wheels/09/d2/49/0d140766d5ee1ef4ce271d302a5d30cf3d18c5b507e48c77f3
# Successfully built dash flask-compress dash-renderer
# Installing collected packages: flask-compress, dash-renderer, dash
# Successfully installed dash-0.36.0 dash-renderer-0.17.0 flask-compress-1.4.0
# Collecting dash-html-components
#   Downloading https://files.pythonhosted.org/packages/91/a3/bd2b7db67c586b3db0234c4385828938d0f5a1281c4e3caee2ca63864b36/dash_html_components-0.13.5.tar.gz (525kB)
#     100% |████████████████████████████████| 532kB 5.8MB/s
# Requirement already satisfied: dash in /usr/local/lib/python3.6/dist-packages (from dash-html-components) (0.36.0)
# Requirement already satisfied: Flask>=0.12 in /usr/local/lib/python3.6/dist-packages (from dash->dash-html-components) (1.0.2)
# Requirement already satisfied: dash-renderer in /usr/local/lib/python3.6/dist-packages (from dash->dash-html-components) (0.17.0)
# Requirement already satisfied: plotly in /usr/local/lib/python3.6/dist-packages (from dash->dash-html-components) (1.12.12)
# Requirement already satisfied: flask-compress in /usr/local/lib/python3.6/dist-packages (from dash->dash-html-components) (1.4.0)
# Requirement already satisfied: click>=5.1 in /usr/local/lib/python3.6/dist-packages (from Flask>=0.12->dash->dash-html-components) (7.0)
# Requirement already satisfied: Jinja2>=2.10 in /usr/local/lib/python3.6/dist-packages (from Flask>=0.12->dash->dash-html-components) (2.10)
# Requirement already satisfied: itsdangerous>=0.24 in /usr/local/lib/python3.6/dist-packages (from Flask>=0.12->dash->dash-html-components) (1.1.0)
# Requirement already satisfied: Werkzeug>=0.14 in /usr/local/lib/python3.6/dist-packages (from Flask>=0.12->dash->dash-html-components) (0.14.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from plotly->dash->dash-html-components) (2.18.4)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from plotly->dash->dash-html-components) (1.11.0)
# Requirement already satisfied: pytz in /usr/local/lib/python3.6/dist-packages (from plotly->dash->dash-html-components) (2018.9)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.6/dist-packages (from Jinja2>=2.10->Flask>=0.12->dash->dash-html-components) (1.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->plotly->dash->dash-html-components) (2018.11.29)
# Requirement already satisfied: idna<2.7,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->plotly->dash->dash-html-components) (2.6)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->plotly->dash->dash-html-components) (3.0.4)
# Requirement already satisfied: urllib3<1.23,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->plotly->dash->dash-html-components) (1.22)
# Building wheels for collected packages: dash-html-components
# done
#   Stored in directory: /root/.cache/pip/wheels/b6/f0/9e/2fc9304ee7bcb5c0b2b06cd22958e004193599b8a4a1e79516
# Successfully built dash-html-components
# Installing collected packages: dash-html-components
# Successfully installed dash-html-components-0.13.5
# Collecting dash-core-components
#   Downloading https://files.pythonhosted.org/packages/ff/b7/131ae0d63089e37b2f2120e1372fd29b614a7f2d2f5db678179eb0ee3b29/dash_core_components-0.43.0.tar.gz (4.1MB)
#     100% |████████████████████████████████| 4.1MB 6.6MB/s
# Requirement already satisfied: dash in /usr/local/lib/python3.6/dist-packages (from dash-core-components) (0.36.0)
# Requirement already satisfied: dash-renderer in /usr/local/lib/python3.6/dist-packages (from dash->dash-core-components) (0.17.0)
# Requirement already satisfied: plotly in /usr/local/lib/python3.6/dist-packages (from dash->dash-core-components) (1.12.12)
# Requirement already satisfied: Flask>=0.12 in /usr/local/lib/python3.6/dist-packages (from dash->dash-core-components) (1.0.2)
# Requirement already satisfied: flask-compress in /usr/local/lib/python3.6/dist-packages (from dash->dash-core-components) (1.4.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from plotly->dash->dash-core-components) (2.18.4)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from plotly->dash->dash-core-components) (1.11.0)
# Requirement already satisfied: pytz in /usr/local/lib/python3.6/dist-packages (from plotly->dash->dash-core-components) (2018.9)
# Requirement already satisfied: itsdangerous>=0.24 in /usr/local/lib/python3.6/dist-packages (from Flask>=0.12->dash->dash-core-components) (1.1.0)
# Requirement already satisfied: Werkzeug>=0.14 in /usr/local/lib/python3.6/dist-packages (from Flask>=0.12->dash->dash-core-components) (0.14.1)
# Requirement already satisfied: Jinja2>=2.10 in /usr/local/lib/python3.6/dist-packages (from Flask>=0.12->dash->dash-core-components) (2.10)
# Requirement already satisfied: click>=5.1 in /usr/local/lib/python3.6/dist-packages (from Flask>=0.12->dash->dash-core-components) (7.0)
# Requirement already satisfied: urllib3<1.23,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->plotly->dash->dash-core-components) (1.22)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->plotly->dash->dash-core-components) (2018.11.29)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->plotly->dash->dash-core-components) (3.0.4)
# Requirement already satisfied: idna<2.7,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->plotly->dash->dash-core-components) (2.6)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.6/dist-packages (from Jinja2>=2.10->Flask>=0.12->dash->dash-core-components) (1.1.0)
# Building wheels for collected packages: dash-core-components
# done
#   Stored in directory: /root/.cache/pip/wheels/cf/21/4d/30149142369e2aa9e75e7956dc992146814a928d2ed73eff39
# Successfully built dash-core-components
# Installing collected packages: dash-core-components
# Successfully installed dash-core-components-0.43.0
# Collecting dash-table
#   Downloading https://files.pythonhosted.org/packages/6f/7e/3abbf72419621f5d0f336940c8b565ed54945e69931d3fc50c96c69593c8/dash_table-3.2.0.tar.gz (305kB)
#     100% |████████████████████████████████| 307kB 4.9MB/s
# Requirement already satisfied: dash in /usr/local/lib/python3.6/dist-packages (from dash-table) (0.36.0)
# Requirement already satisfied: Flask>=0.12 in /usr/local/lib/python3.6/dist-packages (from dash->dash-table) (1.0.2)
# Requirement already satisfied: flask-compress in /usr/local/lib/python3.6/dist-packages (from dash->dash-table) (1.4.0)
# Requirement already satisfied: dash-renderer in /usr/local/lib/python3.6/dist-packages (from dash->dash-table) (0.17.0)
# Requirement already satisfied: plotly in /usr/local/lib/python3.6/dist-packages (from dash->dash-table) (1.12.12)
# Requirement already satisfied: itsdangerous>=0.24 in /usr/local/lib/python3.6/dist-packages (from Flask>=0.12->dash->dash-table) (1.1.0)
# Requirement already satisfied: Werkzeug>=0.14 in /usr/local/lib/python3.6/dist-packages (from Flask>=0.12->dash->dash-table) (0.14.1)
# Requirement already satisfied: click>=5.1 in /usr/local/lib/python3.6/dist-packages (from Flask>=0.12->dash->dash-table) (7.0)
# Requirement already satisfied: Jinja2>=2.10 in /usr/local/lib/python3.6/dist-packages (from Flask>=0.12->dash->dash-table) (2.10)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from plotly->dash->dash-table) (2.18.4)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from plotly->dash->dash-table) (1.11.0)
# Requirement already satisfied: pytz in /usr/local/lib/python3.6/dist-packages (from plotly->dash->dash-table) (2018.9)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.6/dist-packages (from Jinja2>=2.10->Flask>=0.12->dash->dash-table) (1.1.0)
# Requirement already satisfied: urllib3<1.23,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->plotly->dash->dash-table) (1.22)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->plotly->dash->dash-table) (3.0.4)
# Requirement already satisfied: idna<2.7,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->plotly->dash->dash-table) (2.6)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->plotly->dash->dash-table) (2018.11.29)
# Building wheels for collected packages: dash-table
# done
#   Stored in directory: /root/.cache/pip/wheels/95/db/5a/771745f37acec98d58617d6beb6bfa441de8388793b557ba4e
# Successfully built dash-table
# Installing collected packages: dash-table
# Successfully installed dash-table-3.2.0

# %%
# !pip install dash # The core dash backend
# !pip install dash-html-components # HTML components
# !pip install dash-core-components # Supercharged components
# !pip install dash-table # Interactive DataTable component (new!)
# Out:
# Requirement already satisfied: dash in /Users/Pablo/anaconda3/lib/python3.6/site-packages (0.30.0)
# Requirement already satisfied: dash-renderer in /Users/Pablo/anaconda3/lib/python3.6/site-packages (from dash) (0.15.0)
# Requirement already satisfied: Flask>=0.12 in /Users/Pablo/anaconda3/lib/python3.6/site-packages (from dash) (0.12.2)
# Requirement already satisfied: plotly in /Users/Pablo/anaconda3/lib/python3.6/site-packages (from dash) (3.4.1)
# Requirement already satisfied: flask-compress in /Users/Pablo/anaconda3/lib/python3.6/site-packages (from dash) (1.4.0)
# Requirement already satisfied: Werkzeug>=0.7 in /Users/Pablo/anaconda3/lib/python3.6/site-packages (from Flask>=0.12->dash) (0.14.1)
# Requirement already satisfied: Jinja2>=2.4 in /Users/Pablo/anaconda3/lib/python3.6/site-packages (from Flask>=0.12->dash) (2.10)
# Requirement already satisfied: itsdangerous>=0.21 in /Users/Pablo/anaconda3/lib/python3.6/site-packages (from Flask>=0.12->dash) (0.24)
# Requirement already satisfied: click>=2.0 in /Users/Pablo/anaconda3/lib/python3.6/site-packages (from Flask>=0.12->dash) (6.7)
# Requirement already satisfied: nbformat>=4.2 in /Users/Pablo/anaconda3/lib/python3.6/site-packages (from plotly->dash) (4.4.0)
# Requirement already satisfied: six in /Users/Pablo/anaconda3/lib/python3.6/site-packages (from plotly->dash) (1.11.0)
# Requirement already satisfied: requests in /Users/Pablo/anaconda3/lib/python3.6/site-packages (from plotly->dash) (2.12.4)
# Requirement already satisfied: pytz in /Users/Pablo/anaconda3/lib/python3.6/site-packages (from plotly->dash) (2017.3)
# Requirement already satisfied: retrying>=1.3.3 in /Users/Pablo/anaconda3/lib/python3.6/site-packages (from plotly->dash) (1.3.3)
# Requirement already satisfied: decorator>=4.0.6 in /Users/Pablo/anaconda3/lib/python3.6/site-packages (from plotly->dash) (4.2.1)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/Pablo/anaconda3/lib/python3.6/site-packages (from Jinja2>=2.4->Flask>=0.12->dash) (1.0)
# Requirement already satisfied: ipython_genutils in /Users/Pablo/anaconda3/lib/python3.6/site-packages (from nbformat>=4.2->plotly->dash) (0.2.0)
# Requirement already satisfied: traitlets>=4.1 in /Users/Pablo/anaconda3/lib/python3.6/site-packages (from nbformat>=4.2->plotly->dash) (4.3.2)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /Users/Pablo/anaconda3/lib/python3.6/site-packages (from nbformat>=4.2->plotly->dash) (2.6.0)
# Requirement already satisfied: jupyter_core in /Users/Pablo/anaconda3/lib/python3.6/site-packages (from nbformat>=4.2->plotly->dash) (4.4.0)
# You are using pip version 18.1, however version 19.0.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# Requirement already satisfied: dash-html-components in /Users/Pablo/anaconda3/lib/python3.6/site-packages (0.13.2)
# Requirement already satisfied: dash in /Users/Pablo/anaconda3/lib/python3.6/site-packages (from dash-html-components) (0.30.0)
# Requirement already satisfied: flask-compress in /Users/Pablo/anaconda3/lib/python3.6/site-packages (from dash->dash-html-components) (1.4.0)
# Requirement already satisfied: dash-renderer in /Users/Pablo/anaconda3/lib/python3.6/site-packages (from dash->dash-html-components) (0.15.0)
# Requirement already satisfied: Flask>=0.12 in /Users/Pablo/anaconda3/lib/python3.6/site-packages (from dash->dash-html-components) (0.12.2)
# Requirement already satisfied: plotly in /Users/Pablo/anaconda3/lib/python3.6/site-packages (from dash->dash-html-components) (3.4.1)
# Requirement already satisfied: Werkzeug>=0.7 in /Users/Pablo/anaconda3/lib/python3.6/site-packages (from Flask>=0.12->dash->dash-html-components) (0.14.1)
# Requirement already satisfied: Jinja2>=2.4 in /Users/Pablo/anaconda3/lib/python3.6/site-packages (from Flask>=0.12->dash->dash-html-components) (2.10)
# Requirement already satisfied: itsdangerous>=0.21 in /Users/Pablo/anaconda3/lib/python3.6/site-packages (from Flask>=0.12->dash->dash-html-components) (0.24)
# Requirement already satisfied: click>=2.0 in /Users/Pablo/anaconda3/lib/python3.6/site-packages (from Flask>=0.12->dash->dash-html-components) (6.7)
# Requirement already satisfied: retrying>=1.3.3 in /Users/Pablo/anaconda3/lib/python3.6/site-packages (from plotly->dash->dash-html-components) (1.3.3)
# Requirement already satisfied: requests in /Users/Pablo/anaconda3/lib/python3.6/site-packages (from plotly->dash->dash-html-components) (2.12.4)
# Requirement already satisfied: pytz in /Users/Pablo/anaconda3/lib/python3.6/site-packages (from plotly->dash->dash-html-components) (2017.3)
# Requirement already satisfied: decorator>=4.0.6 in /Users/Pablo/anaconda3/lib/python3.6/site-packages (from plotly->dash->dash-html-components) (4.2.1)
# Requirement already satisfied: six in /Users/Pablo/anaconda3/lib/python3.6/site-packages (from plotly->dash->dash-html-components) (1.11.0)
# Requirement already satisfied: nbformat>=4.2 in /Users/Pablo/anaconda3/lib/python3.6/site-packages (from plotly->dash->dash-html-components) (4.4.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/Pablo/anaconda3/lib/python3.6/site-packages (from Jinja2>=2.4->Flask>=0.12->dash->dash-html-components) (1.0)
# Requirement already satisfied: ipython_genutils in /Users/Pablo/anaconda3/lib/python3.6/site-packages (from nbformat>=4.2->plotly->dash->dash-html-components) (0.2.0)
# Requirement already satisfied: traitlets>=4.1 in /Users/Pablo/anaconda3/lib/python3.6/site-packages (from nbformat>=4.2->plotly->dash->dash-html-components) (4.3.2)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /Users/Pablo/anaconda3/lib/python3.6/site-packages (from nbformat>=4.2->plotly->dash->dash-html-components) (2.6.0)
# Requirement already satisfied: jupyter_core in /Users/Pablo/anaconda3/lib/python3.6/site-packages (from nbformat>=4.2->plotly->dash->dash-html-components) (4.4.0)
# You are using pip version 18.1, however version 19.0.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# Requirement already satisfied: dash-core-components in /Users/Pablo/anaconda3/lib/python3.6/site-packages (0.38.0)
# Requirement already satisfied: dash in /Users/Pablo/anaconda3/lib/python3.6/site-packages (from dash-core-components) (0.30.0)
# Requirement already satisfied: Flask>=0.12 in /Users/Pablo/anaconda3/lib/python3.6/site-packages (from dash->dash-core-components) (0.12.2)
# Requirement already satisfied: flask-compress in /Users/Pablo/anaconda3/lib/python3.6/site-packages (from dash->dash-core-components) (1.4.0)
# Requirement already satisfied: dash-renderer in /Users/Pablo/anaconda3/lib/python3.6/site-packages (from dash->dash-core-components) (0.15.0)
# Requirement already satisfied: plotly in /Users/Pablo/anaconda3/lib/python3.6/site-packages (from dash->dash-core-components) (3.4.1)
# Requirement already satisfied: Werkzeug>=0.7 in /Users/Pablo/anaconda3/lib/python3.6/site-packages (from Flask>=0.12->dash->dash-core-components) (0.14.1)
# Requirement already satisfied: Jinja2>=2.4 in /Users/Pablo/anaconda3/lib/python3.6/site-packages (from Flask>=0.12->dash->dash-core-components) (2.10)
# Requirement already satisfied: itsdangerous>=0.21 in /Users/Pablo/anaconda3/lib/python3.6/site-packages (from Flask>=0.12->dash->dash-core-components) (0.24)
# Requirement already satisfied: click>=2.0 in /Users/Pablo/anaconda3/lib/python3.6/site-packages (from Flask>=0.12->dash->dash-core-components) (6.7)
# Requirement already satisfied: retrying>=1.3.3 in /Users/Pablo/anaconda3/lib/python3.6/site-packages (from plotly->dash->dash-core-components) (1.3.3)
# Requirement already satisfied: decorator>=4.0.6 in /Users/Pablo/anaconda3/lib/python3.6/site-packages (from plotly->dash->dash-core-components) (4.2.1)
# Requirement already satisfied: pytz in /Users/Pablo/anaconda3/lib/python3.6/site-packages (from plotly->dash->dash-core-components) (2017.3)
# Requirement already satisfied: requests in /Users/Pablo/anaconda3/lib/python3.6/site-packages (from plotly->dash->dash-core-components) (2.12.4)
# Requirement already satisfied: nbformat>=4.2 in /Users/Pablo/anaconda3/lib/python3.6/site-packages (from plotly->dash->dash-core-components) (4.4.0)
# Requirement already satisfied: six in /Users/Pablo/anaconda3/lib/python3.6/site-packages (from plotly->dash->dash-core-components) (1.11.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/Pablo/anaconda3/lib/python3.6/site-packages (from Jinja2>=2.4->Flask>=0.12->dash->dash-core-components) (1.0)
# Requirement already satisfied: ipython_genutils in /Users/Pablo/anaconda3/lib/python3.6/site-packages (from nbformat>=4.2->plotly->dash->dash-core-components) (0.2.0)
# Requirement already satisfied: traitlets>=4.1 in /Users/Pablo/anaconda3/lib/python3.6/site-packages (from nbformat>=4.2->plotly->dash->dash-core-components) (4.3.2)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /Users/Pablo/anaconda3/lib/python3.6/site-packages (from nbformat>=4.2->plotly->dash->dash-core-components) (2.6.0)
# Requirement already satisfied: jupyter_core in /Users/Pablo/anaconda3/lib/python3.6/site-packages (from nbformat>=4.2->plotly->dash->dash-core-components) (4.4.0)
# You are using pip version 18.1, however version 19.0.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# Requirement already satisfied: dash-table in /Users/Pablo/anaconda3/lib/python3.6/site-packages (3.1.5)
# Requirement already satisfied: dash in /Users/Pablo/anaconda3/lib/python3.6/site-packages (from dash-table) (0.30.0)
# Requirement already satisfied: flask-compress in /Users/Pablo/anaconda3/lib/python3.6/site-packages (from dash->dash-table) (1.4.0)
# Requirement already satisfied: plotly in /Users/Pablo/anaconda3/lib/python3.6/site-packages (from dash->dash-table) (3.4.1)
# Requirement already satisfied: dash-renderer in /Users/Pablo/anaconda3/lib/python3.6/site-packages (from dash->dash-table) (0.15.0)
# Requirement already satisfied: Flask>=0.12 in /Users/Pablo/anaconda3/lib/python3.6/site-packages (from dash->dash-table) (0.12.2)
# Requirement already satisfied: retrying>=1.3.3 in /Users/Pablo/anaconda3/lib/python3.6/site-packages (from plotly->dash->dash-table) (1.3.3)
# Requirement already satisfied: requests in /Users/Pablo/anaconda3/lib/python3.6/site-packages (from plotly->dash->dash-table) (2.12.4)
# Requirement already satisfied: pytz in /Users/Pablo/anaconda3/lib/python3.6/site-packages (from plotly->dash->dash-table) (2017.3)
# Requirement already satisfied: nbformat>=4.2 in /Users/Pablo/anaconda3/lib/python3.6/site-packages (from plotly->dash->dash-table) (4.4.0)
# Requirement already satisfied: six in /Users/Pablo/anaconda3/lib/python3.6/site-packages (from plotly->dash->dash-table) (1.11.0)
# Requirement already satisfied: decorator>=4.0.6 in /Users/Pablo/anaconda3/lib/python3.6/site-packages (from plotly->dash->dash-table) (4.2.1)
# Requirement already satisfied: Werkzeug>=0.7 in /Users/Pablo/anaconda3/lib/python3.6/site-packages (from Flask>=0.12->dash->dash-table) (0.14.1)
# Requirement already satisfied: Jinja2>=2.4 in /Users/Pablo/anaconda3/lib/python3.6/site-packages (from Flask>=0.12->dash->dash-table) (2.10)
# Requirement already satisfied: itsdangerous>=0.21 in /Users/Pablo/anaconda3/lib/python3.6/site-packages (from Flask>=0.12->dash->dash-table) (0.24)
# Requirement already satisfied: click>=2.0 in /Users/Pablo/anaconda3/lib/python3.6/site-packages (from Flask>=0.12->dash->dash-table) (6.7)
# Requirement already satisfied: ipython_genutils in /Users/Pablo/anaconda3/lib/python3.6/site-packages (from nbformat>=4.2->plotly->dash->dash-table) (0.2.0)
# Requirement already satisfied: traitlets>=4.1 in /Users/Pablo/anaconda3/lib/python3.6/site-packages (from nbformat>=4.2->plotly->dash->dash-table) (4.3.2)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /Users/Pablo/anaconda3/lib/python3.6/site-packages (from nbformat>=4.2->plotly->dash->dash-table) (2.6.0)
# Requirement already satisfied: jupyter_core in /Users/Pablo/anaconda3/lib/python3.6/site-packages (from nbformat>=4.2->plotly->dash->dash-table) (4.4.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/Pablo/anaconda3/lib/python3.6/site-packages (from Jinja2>=2.4->Flask>=0.12->dash->dash-table) (1.0)
# You are using pip version 18.1, however version 19.0.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
# %%writefile my_app1.py
#Dash empty structure
import dash
import dash_core_components as dcc
import dash_html_components as html

app = dash.Dash()

app.layout = html.Div('Hello Dash!')

if __name__ == '__main__':
    app.run_server(debug=True)
# Out:
# Overwriting my_app1.py

# %%
# !python3 my_app1.py
# Out:
# Traceback (most recent call last):
#   File "my_app1.py", line 2, in <module>
#     import dash
#   File "/usr/local/lib/python3.6/dist-packages/dash/__init__.py", line 1, in <module>
#     from .dash import Dash  # noqa: F401
#   File "/usr/local/lib/python3.6/dist-packages/dash/dash.py", line 22, in <module>
#     import plotly
#   File "/usr/local/lib/python3.6/dist-packages/plotly/__init__.py", line 31, in <module>
#   File "/usr/local/lib/python3.6/dist-packages/plotly/plotly/__init__.py", line 10, in <module>
#     from . plotly import (
#   File "/usr/local/lib/python3.6/dist-packages/plotly/plotly/plotly.py", line 31, in <module>
#     from plotly import exceptions, tools, utils, version, files
#   File "/usr/local/lib/python3.6/dist-packages/plotly/tools.py", line 20, in <module>
#     from plotly import utils
#   File "/usr/local/lib/python3.6/dist-packages/plotly/utils.py", line 28, in <module>
#     import pandas
#   File "/usr/local/lib/python3.6/dist-packages/pandas/__init__.py", line 42, in <module>
#     from pandas.core.api import *
#   File "/usr/local/lib/python3.6/dist-packages/pandas/core/api.py", line 26, in <module>
#     from pandas.core.reshape.reshape import (
#   File "/usr/local/lib/python3.6/dist-packages/pandas/core/reshape/reshape.py", line 22, in <module>
#     from pandas.core.sparse.api import SparseDataFrame, SparseSeries
#   File "/usr/local/lib/python3.6/dist-packages/pandas/core/sparse/api.py", line 6, in <module>
#     from pandas.core.sparse.frame import SparseDataFrame
#   File "/usr/local/lib/python3.6/dist-packages/pandas/core/sparse/frame.py", line 984, in <module>
#     **ops.frame_special_funcs)
#   File "/usr/local/lib/python3.6/dist-packages/pandas/core/ops.py", line 212, in add_special_arithmetic_methods
#     special=True, have_divmod=have_divmod)
#   File "/usr/local/lib/python3.6/dist-packages/pandas/core/ops.py", line 100, in _create_methods
#     default_axis=default_axis, reversed=True),
#   File "/usr/local/lib/python3.6/dist-packages/pandas/core/ops.py", line 1255, in _arith_method_FRAME
#     def f(self, other, axis=default_axis, level=None, fill_value=None):
#   File "/usr/local/lib/python3.6/dist-packages/pandas/util/_decorators.py", line 244, in __call__
#     func.__doc__ = dedent(self.join.join(docitems))
#   File "/usr/lib/python3.6/textwrap.py", line 431, in dedent
#     indents = _leading_whitespace_re.findall(text)
# KeyboardInterrupt

# %%
# %%writefile my_app2.py
#Dash simple example
import dash
import dash_core_components as dcc
import dash_html_components as html

app = dash.Dash()

app.layout = html.Div([html.H1("Hello Dash!"),
                       
              html.Div('''
                Dash: A web application framework for Python.
              '''),
                      
              dcc.Graph(id='exmaple-graph',
                        figure = {
                            'data':[
                                {'x': [1, 2, 3], 'y': [4.2, 1.8, 2.7], 'type': 'bar', 'name': 'Sabadell'},
                                {'x': [1, 2, 3], 'y': [2.8, 4.9, 5.1], 'type': 'bar', 'name': 'Barcelona'},
                            ],
                            'layout':{
                                'title' : 'Dash Data Visualisation'
                            }
              })
])

if __name__ == '__main__':
    app.run_server(debug=True)
# Out:
# Writing my_app2.py

# %%
# !python3 my_app2.py
# Out:
# Running on http://127.0.0.1:8050/
# Debugger PIN: 757-730-948
#  * Serving Flask app "my_app2" (lazy loading)
#  * Environment: production
#    WARNING: Do not use the development server in a production environment.
#    Use a production WSGI server instead.
#  * Debug mode: on
# Running on http://127.0.0.1:8050/
# Debugger PIN: 806-663-360

# %%
# %%writefile my_app3.py
#Dash simple example
import pandas as pd
import dash
import dash_core_components as dcc
import dash_html_components as html
import plotly.graph_objs as go
from plotly import tools

df = pd.read_csv("DadesSabadell/residus.csv",sep=';')
df.sort_values(by="Anyo",inplace = True)

materials = list(df.NomMaterial.unique())
materials.remove("Resta")

pd.pivot_table(df,columns="Anyo", index = "NomMaterial", values="Quantitat")

minim = 0
maxim = 1000
pas = 100

app = dash.Dash()
app.css.append_css({"external_url": "https://codepen.io/chriddyp/pen/bWLwgP.css"})

app.layout = html.Div([html.Div([dcc.Graph(id='residus_graph')],
                                style={'height':'80%','padding': '0px 20px 20px 20px'}),
                                html.Div([html.H5("Materials amb mitjana de tones per any més grans que:"),
                                    dcc.Slider(id='avg-tones',step = pas,min=minim,max=maxim,value=maxim/2,       
                                            marks={ str(tones): {'label':str(tones)} for tones in range(minim,maxim+pas,pas)})],
                       style={'margin':'auto','height':'20%','width': '70%', 'padding': '0px 0px 40px 40px',"display":'inline_block'})])

@app.callback(
    dash.dependencies.Output('residus_graph', 'figure'),
    [dash.dependencies.Input('avg-tones', 'value')])

def update_figure(avg_tones):
    fig = tools.make_subplots(rows=2, cols=1,shared_xaxes=True, vertical_spacing=0.001)
    traces = []
    
    filtered= df[df['NomMaterial'] =="Resta"]
    trace_Resta = go.Scatter(
                            x=filtered['Anyo'],y=filtered['Quantitat'],text="Resta",
                            mode='lines+markers',
                            opacity=0.7,
                            marker={
                                'size': 15,
                                'line': {'width': 0.5, 'color': 'white'}
                            },
                            name="Resta"
                        )  
    
    filtered = df[df['NomMaterial'].isin(materials)].groupby("Anyo").sum()
    trace_Total= go.Scatter(                      
                            x=filtered.index,y=filtered['Quantitat'],text="Total Materials",
                            mode='lines+markers',
                            opacity=0.7,
                            marker={
                                'size': 15,
                                'line': {'width': 0.5, 'color': 'white'}
                            },
                            name="Total Materials",
                            
                        )   
    
    fig.append_trace(trace_Resta, 1, 1)
    fig.append_trace(trace_Total, 1, 1)
    
    for i in materials :
        filtered= df[df['NomMaterial'] == i]
        y=filtered['Quantitat']
        if (y.mean()>avg_tones) :
            x=filtered['Anyo']
            traces.append(go.Scatter(x=x,y=y,text=i,mode='markers',opacity=0.7,
                                marker={
                                    'size': 15,
                                    'line': {'width': 0.5, 'color': 'white'}
                                }, name=i[0:30])) 
    for trace in traces:
        fig.append_trace(trace, 2, 1)


    fig['layout'].update(height=600,title="Residus a Sabadell", margin={'l': 50, 'b': 40, 't': 40, 'r': 50},
              yaxis1={"title":"Totals"}, yaxis2={"title":"Materials"},hovermode="closest")
    return fig


if __name__ == '__main__':
    app.run_server()

# %%
# !python3 my_app3.py

# %% [markdown]
# # Open Data Barcelona
#
# **EXERCICE**
#
# Using information of 2017's births in Barcelona Districts that you can find at [Open Data Barcelona](http://opendata-ajuntament.barcelona.cat/en/) that you can download [here](http://opendata-ajuntament.barcelona.cat/data/en/dataset/est-demo-naixements-sexe), try to obtain a fancy plot showing girls and boys births per different Barcelona District(Slicer is not necessary).
#
# You also can find this the CSV file with this information in `DadesBarcelona/2017_naixements_sexe.csv`

# %%
import pandas as pd

df = pd.read_csv("DadesBarcelona/2017_naixements_sexe.csv",sep=',')

df

# %%
#pd.pivot_table()

# %%
# %%writefile my_exercice.py
#Dash exercice
import pandas as pd
import dash
import dash_core_components as dcc
import dash_html_components as html
import plotly.graph_objs as go
from plotly import tools
import numpy as np

df = pd.read_csv("DadesBarcelona/2017_naixements_sexe.csv",sep=',')
#pv = pd.pivot_table() ADD YOUR CODE

app = dash.Dash()
app.css.append_css({"external_url": "https://codepen.io/chriddyp/pen/bWLwgP.css"})

app.layout = html.Div([html.Div(
    [dcc.Graph(id='birth_bcn',figure = {
        
                                    #YOUR CODE HERE
         
                              } )
                                ],
                                style={'height':'80%','padding': '0px 20px 20px 20px'},
                                
                               )])




if __name__ == '__main__':
    app.run_server(debug=True)


if __name__ == '__main__':
    app.run_server()

# %%
# !python3 my_exercice.py
