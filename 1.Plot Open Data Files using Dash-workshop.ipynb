# %%
import os
from google.colab import drive
drive.mount('/gdrive', force_remount=True)

root_dir = '/gdrive/My Drive/datascience/workshops/Data_and_interactive_plots/'
for f in os.listdir(root_dir):
  print(f)
# Out:
# Mounted at /gdrive
# 1.Plot Open Data Files using Dash-EMPTY.ipynb
# requirements.txt
# 3. Searching info using APIs-EMPTY.ipynb
# 1.Plot Open Data Files using Dash.ipynb
# 2. Ploting information in Maps.ipynb
# DadesSabadell
# README.md
# 4. Sabadell Cinema Example.ipynb
# DadesBarcelona
# LICENSE.md
# .git
# .gitignore

# %% [markdown]
# # Open Data Sabadell
#
#
# http://opendata.sabadell.cat/ca/
#
# From main page **Catàleg** we select **Medi Ambient** (Environment) category.
# In there, we can find a file related to municipal waste that can be downloaded from [here.](http://opendata.sabadell.cat/index.php?option=com_iasopendata&view=download&format=raw&urlOData=aHR0cDovL29kYXRhLnNhYmFkZWxsLmNhdC9vZGF0YTRQcm9kdWN0b3Ivb2RhdGE0UHJvZHVjdG9yLnN2Yy9NYXRlcmlhbHNSZXNpZHVzLz9mb3JtYXQ9Y3N2JmlkZGlzdD0xNDYyJiRzZWxlY3Q9T3JkcmUsQW55byxJZE1hdGVyaWFsLE5vbU1hdGVyaWFsLFF1YW50aXRhdCxVbml0YXRz) But you can find a copy of this file named **residus.csv** in this tutorial dataset in **DadesSabadell** folder.
#
# The file obtained is in a CSV format (Comma Separated Value). This means that it is
# like a table where the rows are registers and the columns are fields or values associated to this register.
#
# You can take a look into this file in table-like representation provided in the open data web page following this link: [OpenData Sabadell](http://opendata.sabadell.cat/ca/inici/odata?iddist=1462). Looking this table we can observe that every register represents an amount of waste origined in Sabadell in tones associated with a particular year and a waste type classification.
#
# In this exercice we are going to follow this steps:
# * Read residus.csv file.
# * Group data to obtain more readable information. Every row will be a type of waste and the columns will be a year related to this data.
# * Represent data in an interactive way.
#
# **Important:** Nan values indicate that there is no infomation related to this type of waste and year.

# %% [markdown]
# To read data and manage it we are going to use [pandas](https://pandas.pydata.org/) library:

# %%
import pandas as pd

#df = pd.read_csv(root_dir + "DadesSabadell/residus.csv",sep=';')
df = pd.read_csv("DadesSabadell/residus.csv",sep=';')

df.sort_values(by="Anyo",inplace = True)

df.head()
# Out:
#      Ordre  Anyo  IdMaterial      NomMaterial  Quantitat Unitats
# 339    338  1984          28      Voluminosos        NaN   Tones
# 390    389  1984           2            Paper        NaN   Tones
# 179    179  1984           3          Envasos        NaN   Tones
# 247    246  1984          16            Piles        NaN   Tones
# 234    233  1984           9  Fracció vegetal        NaN   Tones

# %%
materials = list(df.NomMaterial.unique())
materials.remove("Resta")

print ('{} diferent types of wastes:'.format(len(materials)))
materials
# Out:
# 45 diferent types of wastes:
# ['Voluminosos',
#  'Paper',
#  'Envasos',
#  'Piles',
#  'Fracció vegetal',
#  'Vidre',
#  'Tèxtil',
#  'Medicaments i cosmètics',
#  'Olis vegetals',
#  'Ferralla',
#  'Vidre Pla',
#  'Runes',
#  'Fusta',
#  'Sòlids i Pastosos',
#  'Àcids',
#  'Aerosols',
#  'RAEE A1: Aparells de fred, frigorífics...',
#  'Tòners',
#  'Olis minerals',
#  'Dissolvents',
#  'Reactius de laboratori',
#  'Pneumàtics',
#  'RAEE A3: Televisors i monitors',
#  'Comburents',
#  'RAEE A2: Grans electrodomèstics assecadores, rentadores...',
#  'Coure',
#  'Càpsules de cafè',
#  'RAEE A5: làmpares fluorescents',
#  'Bases',
#  'Bateries',
#  'Medicaments',
#  'RAEE A4: Ordinadors, aspiradores, joguines elèctriques i electròniques....',
#  'Altres residus especials',
#  'Materia orgànica',
#  'Radiografies',
#  'Porexpan',
#  'Plàstic rígid',
#  'Cd i DVD',
#  'Cartró',
#  "RAEE FRA 6 (A4) Aparells petits d'informàtica i telecomunicacions ",
#  'RAEE FRA 5 (A4) Petits aparells sense dimensió superior a 50 cm',
#  'RAEE FRA 4 (A2) Altres aparells amb tamany superior a 50 cm no inclosos en FRA 1',
#  'RAEE FRA 3 (A5) Lampares i fluorescents',
#  'RAEE FRA 2 (A3) Monitors i pantalles LED, CRT i altres',
#  "RAEE FRA (A1) Grans aparells d'intercanvi de temperatura, frigotrifics, aire acondicionat..."]

# %%
pd.pivot_table(df,columns="Anyo", index = "NomMaterial", values="Quantitat")
# Out:
# Anyo                                                1984     1985     1986  \
# NomMaterial
# Aerosols                                             NaN      NaN      NaN
# Altres residus especials                             NaN      NaN      NaN
# Bases                                                NaN      NaN      NaN
# Bateries                                             NaN      NaN      NaN
# Cartró                                               NaN      NaN      NaN
# Cd i DVD                                             NaN      NaN      NaN
# Comburents                                           NaN      NaN      NaN
# Coure                                                NaN      NaN      NaN
# Càpsules de cafè                                     NaN      NaN      NaN
# Dissolvents                                          NaN      NaN      NaN
# Envasos                                              NaN      NaN      NaN
# Ferralla                                             NaN      NaN      NaN
# Fracció vegetal                                      NaN      NaN      NaN
# Fusta                                                NaN      NaN      NaN
# Materia orgànica                                     NaN      NaN      NaN
# Medicaments                                          NaN      NaN      NaN
# Medicaments i cosmètics                              NaN      NaN      NaN
# Olis minerals                                        NaN      NaN      NaN
# Olis vegetals                                        NaN      NaN      NaN
# Paper                                                NaN      NaN      NaN
# Piles                                                NaN      NaN      NaN
# Plàstic rígid                                        NaN      NaN      NaN
# Pneumàtics                                           NaN      NaN      NaN
# Porexpan                                             NaN      NaN      NaN
# RAEE A1: Aparells de fred, frigorífics...            NaN      NaN      NaN
# RAEE A2: Grans electrodomèstics assecadores, re...   NaN      NaN      NaN
# RAEE A3: Televisors i monitors                       NaN      NaN      NaN
# RAEE A4: Ordinadors, aspiradores, joguines elèc...   NaN      NaN      NaN
# RAEE A5: làmpares fluorescents                       NaN      NaN      NaN
# RAEE FRA (A1) Grans aparells d'intercanvi de te...   NaN      NaN      NaN
# RAEE FRA 2 (A3) Monitors i pantalles LED, CRT i...   NaN      NaN      NaN
# RAEE FRA 3 (A5) Lampares i fluorescents              NaN      NaN      NaN
# RAEE FRA 4 (A2) Altres aparells amb tamany supe...   NaN      NaN      NaN
# RAEE FRA 5 (A4) Petits aparells sense dimensió ...   NaN      NaN      NaN
# RAEE FRA 6 (A4) Aparells petits d'informàtica i...   NaN      NaN      NaN
# Radiografies                                         NaN      NaN      NaN
# Reactius de laboratori                               NaN      NaN      NaN
# Resta                                                NaN  49485.0  50894.0
# Runes                                                NaN      NaN      NaN
# Sòlids i Pastosos                                    NaN      NaN      NaN
# Tèxtil                                               NaN      NaN      NaN
# Tòners                                               NaN      NaN      NaN
# Vidre                                               46.0    103.0    204.0
# Vidre Pla                                            NaN      NaN      NaN
# Voluminosos                                          NaN      NaN      NaN
# Àcids                                                NaN      NaN      NaN
#
# Anyo                                                   1987     1988   1989  \
# NomMaterial
# Aerosols                                                NaN      NaN    NaN
# Altres residus especials                                NaN      NaN    NaN
# Bases                                                   NaN      NaN    NaN
# Bateries                                                NaN      NaN    NaN
# Cartró                                                  NaN      NaN    NaN
# Cd i DVD                                                NaN      NaN    NaN
# Comburents                                              NaN      NaN    NaN
# Coure                                                   NaN      NaN    NaN
# Càpsules de cafè                                        NaN      NaN    NaN
# Dissolvents                                             NaN      NaN    NaN
# Envasos                                                 NaN      NaN    NaN
# Ferralla                                                NaN      NaN    NaN
# Fracció vegetal                                         NaN      NaN    NaN
# Fusta                                                   NaN      NaN    NaN
# Materia orgànica                                        NaN      NaN    NaN
# Medicaments                                             NaN      NaN    NaN
# Medicaments i cosmètics                                 NaN      NaN    NaN
# Olis minerals                                           NaN      NaN    NaN
# Olis vegetals                                           NaN      NaN    NaN
# Paper                                                   NaN      NaN    NaN
# Piles                                                   NaN      NaN    NaN
# Plàstic rígid                                           NaN      NaN    NaN
# Pneumàtics                                              NaN      NaN    NaN
# Porexpan                                                NaN      NaN    NaN
# RAEE A1: Aparells de fred, frigorífics...               NaN      NaN    NaN
# RAEE A2: Grans electrodomèstics assecadores, re...      NaN      NaN    NaN
# RAEE A3: Televisors i monitors                          NaN      NaN    NaN
# RAEE A4: Ordinadors, aspiradores, joguines elèc...      NaN      NaN    NaN
# RAEE A5: làmpares fluorescents                          NaN      NaN    NaN
# RAEE FRA (A1) Grans aparells d'intercanvi de te...      NaN      NaN    NaN
# RAEE FRA 2 (A3) Monitors i pantalles LED, CRT i...      NaN      NaN    NaN
# RAEE FRA 3 (A5) Lampares i fluorescents                 NaN      NaN    NaN
# RAEE FRA 4 (A2) Altres aparells amb tamany supe...      NaN      NaN    NaN
# RAEE FRA 5 (A4) Petits aparells sense dimensió ...      NaN      NaN    NaN
# RAEE FRA 6 (A4) Aparells petits d'informàtica i...      NaN      NaN    NaN
# Radiografies                                            NaN      NaN    NaN
# Reactius de laboratori                                  NaN      NaN    NaN
# Resta                                               54649.0  57987.0    NaN
# Runes                                                   NaN      NaN    NaN
# Sòlids i Pastosos                                       NaN      NaN    NaN
# Tèxtil                                                  NaN      NaN    NaN
# Tòners                                                  NaN      NaN    NaN
# Vidre                                                 317.0      NaN  373.0
# Vidre Pla                                               NaN      NaN    NaN
# Voluminosos                                             NaN      NaN    NaN
# Àcids                                                   NaN      NaN    NaN
#
# Anyo                                                   1990     1991     1992  \
# NomMaterial
# Aerosols                                                NaN      NaN      NaN
# Altres residus especials                                NaN      NaN      NaN
# Bases                                                   NaN      NaN      NaN
# Bateries                                                NaN      NaN      NaN
# Cartró                                                  NaN      NaN      NaN
# Cd i DVD                                                NaN      NaN      NaN
# Comburents                                              NaN      NaN      NaN
# Coure                                                   NaN      NaN      NaN
# Càpsules de cafè                                        NaN      NaN      NaN
# Dissolvents                                             NaN      NaN      NaN
# Envasos                                                 NaN      NaN      NaN
# Ferralla                                                NaN      NaN      NaN
# Fracció vegetal                                         NaN      NaN      NaN
# Fusta                                                   NaN      NaN      NaN
# Materia orgànica                                        NaN      NaN      NaN
# Medicaments                                             NaN      NaN      NaN
# Medicaments i cosmètics                                 NaN      NaN      NaN
# Olis minerals                                           NaN      NaN      NaN
# Olis vegetals                                           NaN      NaN      NaN
# Paper                                                   NaN      NaN      NaN
# Piles                                                   NaN      NaN      NaN
# Plàstic rígid                                           NaN      NaN      NaN
# Pneumàtics                                              NaN      NaN      NaN
# Porexpan                                                NaN      NaN      NaN
# RAEE A1: Aparells de fred, frigorífics...               NaN      NaN      NaN
# RAEE A2: Grans electrodomèstics assecadores, re...      NaN      NaN      NaN
# RAEE A3: Televisors i monitors                          NaN      NaN      NaN
# RAEE A4: Ordinadors, aspiradores, joguines elèc...      NaN      NaN      NaN
# RAEE A5: làmpares fluorescents                          NaN      NaN      NaN
# RAEE FRA (A1) Grans aparells d'intercanvi de te...      NaN      NaN      NaN
# RAEE FRA 2 (A3) Monitors i pantalles LED, CRT i...      NaN      NaN      NaN
# RAEE FRA 3 (A5) Lampares i fluorescents                 NaN      NaN      NaN
# RAEE FRA 4 (A2) Altres aparells amb tamany supe...      NaN      NaN      NaN
# RAEE FRA 5 (A4) Petits aparells sense dimensió ...      NaN      NaN      NaN
# RAEE FRA 6 (A4) Aparells petits d'informàtica i...      NaN      NaN      NaN
# Radiografies                                            NaN      NaN      NaN
# Reactius de laboratori                                  NaN      NaN      NaN
# Resta                                               63035.0  71728.0  77390.0
# Runes                                                   NaN      NaN      NaN
# Sòlids i Pastosos                                       NaN      NaN      NaN
# Tèxtil                                                  NaN      NaN      NaN
# Tòners                                                  NaN      NaN      NaN
# Vidre                                                 397.0    560.0    735.0
# Vidre Pla                                               NaN      NaN      NaN
# Voluminosos                                             NaN      NaN      NaN
# Àcids                                                   NaN      NaN      NaN
#
# Anyo                                                   1993   ...        2009  \
# NomMaterial                                                   ...
# Aerosols                                                NaN   ...         1.0
# Altres residus especials                                NaN   ...         1.0
# Bases                                                   NaN   ...         0.0
# Bateries                                                NaN   ...        13.0
# Cartró                                                  NaN   ...         NaN
# Cd i DVD                                                NaN   ...         0.0
# Comburents                                              NaN   ...         0.0
# Coure                                                   NaN   ...         1.0
# Càpsules de cafè                                        NaN   ...         3.0
# Dissolvents                                             NaN   ...         7.0
# Envasos                                                 NaN   ...      4244.0
# Ferralla                                                NaN   ...       378.0
# Fracció vegetal                                         NaN   ...       859.0
# Fusta                                                   NaN   ...      2423.0
# Materia orgànica                                        NaN   ...      6799.0
# Medicaments                                             NaN   ...        18.0
# Medicaments i cosmètics                                 NaN   ...         0.0
# Olis minerals                                           NaN   ...        26.0
# Olis vegetals                                           NaN   ...        24.0
# Paper                                                   NaN   ...         NaN
# Piles                                                   NaN   ...        22.0
# Plàstic rígid                                           NaN   ...       126.0
# Pneumàtics                                              NaN   ...        24.0
# Porexpan                                                NaN   ...        24.0
# RAEE A1: Aparells de fred, frigorífics...               NaN   ...        34.0
# RAEE A2: Grans electrodomèstics assecadores, re...      NaN   ...        66.0
# RAEE A3: Televisors i monitors                          NaN   ...         NaN
# RAEE A4: Ordinadors, aspiradores, joguines elèc...      NaN   ...         NaN
# RAEE A5: làmpares fluorescents                          NaN   ...         9.0
# RAEE FRA (A1) Grans aparells d'intercanvi de te...      NaN   ...         NaN
# RAEE FRA 2 (A3) Monitors i pantalles LED, CRT i...      NaN   ...         NaN
# RAEE FRA 3 (A5) Lampares i fluorescents                 NaN   ...         NaN
# RAEE FRA 4 (A2) Altres aparells amb tamany supe...      NaN   ...         NaN
# RAEE FRA 5 (A4) Petits aparells sense dimensió ...      NaN   ...         NaN
# RAEE FRA 6 (A4) Aparells petits d'informàtica i...      NaN   ...         NaN
# Radiografies                                            NaN   ...         NaN
# Reactius de laboratori                                  NaN   ...         2.0
# Resta                                               78710.0   ...     69412.0
# Runes                                                   NaN   ...      2905.0
# Sòlids i Pastosos                                       NaN   ...        58.0
# Tèxtil                                                  NaN   ...       200.0
# Tòners                                                  NaN   ...         0.0
# Vidre                                                   NaN   ...      3266.0
# Vidre Pla                                               NaN   ...       409.0
# Voluminosos                                             NaN   ...         NaN
# Àcids                                                   NaN   ...         NaN
#
# Anyo                                                   2010     2011     2012  \
# NomMaterial
# Aerosols                                                1.0      1.0      0.0
# Altres residus especials                                1.0      1.0      2.0
# Bases                                                   0.0      0.0      0.0
# Bateries                                               12.0      9.0     14.0
# Cartró                                                  NaN     52.0     20.0
# Cd i DVD                                                2.0      NaN      1.0
# Comburents                                              0.0      0.0      0.0
# Coure                                                   1.0      1.0      NaN
# Càpsules de cafè                                        NaN      NaN      NaN
# Dissolvents                                             8.0      NaN      4.0
# Envasos                                              4318.0   4340.0   4057.0
# Ferralla                                                NaN    166.0     98.0
# Fracció vegetal                                      1040.0    345.0    137.0
# Fusta                                                2568.0   2326.0      NaN
# Materia orgànica                                     6896.0   7131.0   6924.0
# Medicaments                                            19.0      NaN      NaN
# Medicaments i cosmètics                                 NaN      0.0      0.0
# Olis minerals                                           NaN     15.0     12.0
# Olis vegetals                                          29.0     28.0     26.0
# Paper                                                9029.0   7091.0   4971.0
# Piles                                                  22.0      9.0     16.0
# Plàstic rígid                                         113.0    102.0     70.0
# Pneumàtics                                              7.0      NaN      NaN
# Porexpan                                                9.0     14.0      1.0
# RAEE A1: Aparells de fred, frigorífics...              69.0     16.0      NaN
# RAEE A2: Grans electrodomèstics assecadores, re...      NaN     40.0     27.0
# RAEE A3: Televisors i monitors                        159.0    107.0     69.0
# RAEE A4: Ordinadors, aspiradores, joguines elèc...     87.0     73.0     57.0
# RAEE A5: làmpares fluorescents                          NaN      6.0      4.0
# RAEE FRA (A1) Grans aparells d'intercanvi de te...      NaN      NaN      NaN
# RAEE FRA 2 (A3) Monitors i pantalles LED, CRT i...      NaN      NaN      NaN
# RAEE FRA 3 (A5) Lampares i fluorescents                 NaN      NaN      NaN
# RAEE FRA 4 (A2) Altres aparells amb tamany supe...      NaN      NaN      NaN
# RAEE FRA 5 (A4) Petits aparells sense dimensió ...      NaN      NaN      NaN
# RAEE FRA 6 (A4) Aparells petits d'informàtica i...      NaN      NaN      NaN
# Radiografies                                            NaN      NaN      1.0
# Reactius de laboratori                                  NaN      2.0      1.0
# Resta                                               67551.0  64594.0  60046.0
# Runes                                                3577.0   4565.0   4556.0
# Sòlids i Pastosos                                      57.0     45.0     20.0
# Tèxtil                                                213.0      NaN    195.0
# Tòners                                                  NaN      NaN      NaN
# Vidre                                                3129.0   3040.0      NaN
# Vidre Pla                                             379.0    332.0    285.0
# Voluminosos                                          4544.0   4496.0   1866.0
# Àcids                                                   0.0      0.0      0.0
#
# Anyo                                                   2013     2014    2015  \
# NomMaterial
# Aerosols                                                NaN      1.0     NaN
# Altres residus especials                               37.0      NaN     NaN
# Bases                                                   NaN      0.0     NaN
# Bateries                                               26.0      NaN     3.0
# Cartró                                                  NaN      NaN     NaN
# Cd i DVD                                                1.0      1.0     NaN
# Comburents                                              NaN      NaN     NaN
# Coure                                                   0.0      0.0     0.0
# Càpsules de cafè                                        NaN      NaN     NaN
# Dissolvents                                             6.0      5.0     NaN
# Envasos                                                 NaN   3999.0  3329.0
# Ferralla                                              111.0    127.0     NaN
# Fracció vegetal                                       400.0      NaN   274.0
# Fusta                                                1876.0    948.0  1233.0
# Materia orgànica                                     7069.0   6596.0     NaN
# Medicaments                                             NaN      NaN     NaN
# Medicaments i cosmètics                                 NaN      3.0     NaN
# Olis minerals                                          10.0      8.0     9.0
# Olis vegetals                                           NaN     34.0    19.0
# Paper                                                4429.0   4340.0  3923.0
# Piles                                                  14.0     15.0     4.0
# Plàstic rígid                                          86.0     45.0    33.0
# Pneumàtics                                             20.0     15.0    15.0
# Porexpan                                                1.0      1.0    10.0
# RAEE A1: Aparells de fred, frigorífics...              12.0     15.0    20.0
# RAEE A2: Grans electrodomèstics assecadores, re...     22.0     23.0    31.0
# RAEE A3: Televisors i monitors                         63.0     56.0    52.0
# RAEE A4: Ordinadors, aspiradores, joguines elèc...     49.0      NaN    47.0
# RAEE A5: làmpares fluorescents                          3.0      7.0     NaN
# RAEE FRA (A1) Grans aparells d'intercanvi de te...      NaN      NaN     NaN
# RAEE FRA 2 (A3) Monitors i pantalles LED, CRT i...      NaN      NaN     NaN
# RAEE FRA 3 (A5) Lampares i fluorescents                 NaN      NaN     NaN
# RAEE FRA 4 (A2) Altres aparells amb tamany supe...      NaN      NaN     NaN
# RAEE FRA 5 (A4) Petits aparells sense dimensió ...      NaN      NaN     NaN
# RAEE FRA 6 (A4) Aparells petits d'informàtica i...      NaN      NaN     NaN
# Radiografies                                            0.0      NaN     0.0
# Reactius de laboratori                                  NaN      0.0     NaN
# Resta                                               56172.0  57009.0     NaN
# Runes                                                   NaN   3229.0  3387.0
# Sòlids i Pastosos                                       NaN     33.0     NaN
# Tèxtil                                                277.0    273.0   344.0
# Tòners                                                  NaN      NaN     NaN
# Vidre                                                3107.0   2956.0  3129.0
# Vidre Pla                                             293.0    276.0   342.0
# Voluminosos                                          1656.0   4160.0  4540.0
# Àcids                                                   NaN      0.0     NaN
#
# Anyo                                                   2016     2017     2018
# NomMaterial
# Aerosols                                                NaN      NaN      NaN
# Altres residus especials                                NaN      6.0      NaN
# Bases                                                   NaN      1.0      NaN
# Bateries                                                3.0      2.0      2.0
# Cartró                                                  NaN      NaN      NaN
# Cd i DVD                                                NaN      1.0      NaN
# Comburents                                              NaN      6.0      NaN
# Coure                                                   1.0      0.0      1.0
# Càpsules de cafè                                        NaN      2.0      NaN
# Dissolvents                                             NaN      9.0      NaN
# Envasos                                              2665.0   2806.0   2576.0
# Ferralla                                              109.0    120.0    158.0
# Fracció vegetal                                       867.0    559.0    112.0
# Fusta                                                1548.0   2279.0   1700.0
# Materia orgànica                                     4897.0   4718.0   4088.0
# Medicaments                                             NaN      NaN      NaN
# Medicaments i cosmètics                                 NaN      1.0      NaN
# Olis minerals                                           8.0      NaN      4.0
# Olis vegetals                                          33.0     31.0     10.0
# Paper                                                   NaN   4097.0   3613.0
# Piles                                                   0.0      6.0      0.0
# Plàstic rígid                                          44.0     43.0     34.0
# Pneumàtics                                              3.0      9.0      NaN
# Porexpan                                                0.0      1.0      1.0
# RAEE A1: Aparells de fred, frigorífics...              26.0      NaN      NaN
# RAEE A2: Grans electrodomèstics assecadores, re...     36.0      NaN      NaN
# RAEE A3: Televisors i monitors                          NaN      NaN      NaN
# RAEE A4: Ordinadors, aspiradores, joguines elèc...     43.0      NaN      NaN
# RAEE A5: làmpares fluorescents                          3.0      NaN      NaN
# RAEE FRA (A1) Grans aparells d'intercanvi de te...      5.0     39.0      NaN
# RAEE FRA 2 (A3) Monitors i pantalles LED, CRT i...     13.0     51.0     28.0
# RAEE FRA 3 (A5) Lampares i fluorescents                 1.0      2.0      2.0
# RAEE FRA 4 (A2) Altres aparells amb tamany supe...      4.0     41.0      NaN
# RAEE FRA 5 (A4) Petits aparells sense dimensió ...      6.0     34.0     18.0
# RAEE FRA 6 (A4) Aparells petits d'informàtica i...      4.0     27.0     16.0
# Radiografies                                            NaN      0.0      NaN
# Reactius de laboratori                                  NaN      0.0      NaN
# Resta                                               61177.0  60747.0  46530.0
# Runes                                                4225.0   4299.0   3268.0
# Sòlids i Pastosos                                       NaN     39.0      NaN
# Tèxtil                                                391.0    408.0      NaN
# Tòners                                                  0.0      4.0      3.0
# Vidre                                                3030.0   3112.0   2775.0
# Vidre Pla                                             322.0    301.0    249.0
# Voluminosos                                             NaN   5606.0   4144.0
# Àcids                                                   NaN      0.0      NaN
#
# [46 rows x 35 columns]

# %% [markdown]
# All is prepared to plot our data. We are going to us Dash (web-based interfaces in Python) to plot information and give them interactivity.
#
# If you are interested to learn more about Dash you can follow the offical [tutorial.](https://dash.plot.ly/)
#
# [Dash installation:](https://dash.plot.ly/installation)
#
# * **pip install dash**  # The core dash backend
# * **pip install dash-html-components**  # HTML components
# * **pip install dash-core-components**  # Supercharged components
# * **pip install dash-table**  # Interactive DataTable component (new!)

# %%
# !pip install dash # The core dash backend
# !pip install dash-html-components # HTML components
# !pip install dash-core-components # Supercharged components
# !pip install dash-table # Interactive DataTable component (new!)
# Out:
# Solving environment: failed
#
# PackagesNotFoundError: The following packages are not available from current channels:
#
#   - dash
#
# Current channels:
#
#   - https://repo.anaconda.com/pkgs/main/osx-64
#   - https://repo.anaconda.com/pkgs/main/noarch
#   - https://repo.anaconda.com/pkgs/free/osx-64
#   - https://repo.anaconda.com/pkgs/free/noarch
#   - https://repo.anaconda.com/pkgs/r/osx-64
#   - https://repo.anaconda.com/pkgs/r/noarch
#   - https://repo.anaconda.com/pkgs/pro/osx-64
#   - https://repo.anaconda.com/pkgs/pro/noarch
#
# To search for alternate channels that may provide the conda package you're
# looking for, navigate to
#
#     https://anaconda.org
#
# and use the search bar at the top of the page.
#
#
# Solving environment: failed
#
# PackagesNotFoundError: The following packages are not available from current channels:
#
#   - dash-html-components
#
# Current channels:
#
#   - https://repo.anaconda.com/pkgs/main/osx-64
#   - https://repo.anaconda.com/pkgs/main/noarch
#   - https://repo.anaconda.com/pkgs/free/osx-64
#   - https://repo.anaconda.com/pkgs/free/noarch
#   - https://repo.anaconda.com/pkgs/r/osx-64
#   - https://repo.anaconda.com/pkgs/r/noarch
#   - https://repo.anaconda.com/pkgs/pro/osx-64
#   - https://repo.anaconda.com/pkgs/pro/noarch
#
# To search for alternate channels that may provide the conda package you're
# looking for, navigate to
#
#     https://anaconda.org
#
# and use the search bar at the top of the page.
#
#
# Solving environment: failed
#
# PackagesNotFoundError: The following packages are not available from current channels:
#
#   - dash-core-components
#
# Current channels:
#
#   - https://repo.anaconda.com/pkgs/main/osx-64
#   - https://repo.anaconda.com/pkgs/main/noarch
#   - https://repo.anaconda.com/pkgs/free/osx-64
#   - https://repo.anaconda.com/pkgs/free/noarch
#   - https://repo.anaconda.com/pkgs/r/osx-64
#   - https://repo.anaconda.com/pkgs/r/noarch
#   - https://repo.anaconda.com/pkgs/pro/osx-64
#   - https://repo.anaconda.com/pkgs/pro/noarch
#
# To search for alternate channels that may provide the conda package you're
# looking for, navigate to
#
#     https://anaconda.org
#
# and use the search bar at the top of the page.
#
#
# Solving environment: / ^C
# failed
#
# CondaError: KeyboardInterrupt

# %%
# %%writefile my_app1.py
#Dash empty structure
import dash
import dash_core_components as dcc
import dash_html_components as html

app = dash.Dash()

app.layout = html.Div('Hello Dash!')

if __name__ == '__main__':
    app.run_server(debug=True)
# Out:
# Overwriting my_app1.py

# %%
# !python my_app1.py
# Out:
# Running on http://127.0.0.1:8050/
# Debugger PIN: 118-146-661
# Running on http://127.0.0.1:8050/
# Debugger PIN: 392-405-073
# ^C

# %%
# %%writefile my_app2.py
#Dash simple example
import dash
import dash_core_components as dcc
import dash_html_components as html

app = dash.Dash()

app.layout = html.Div([html.H1("Hello Dash!"),
                       
              html.Div('''
                Dash: A web application framework for Python.
              '''),
                      
              dcc.Graph(id='exmaple-graph',
                        figure = {
                            'data':[
                                {'x': [1, 2, 3], 'y': [4.2, 1.8, 2.7], 'type': 'bar', 'name': 'Sabadell'},
                                {'x': [1, 2, 3], 'y': [2.8, 4.9, 5.1], 'type': 'bar', 'name': 'Barcelona'},
                            ],
                            'layout':{
                                'title' : 'Dash Data Visualisation'
                            }
              })
])

if __name__ == '__main__':
    app.run_server(debug=True)
# Out:
# Writing my_app2.py

# %%
# !python my_app2.py
# Out:
# ^C
# Traceback (most recent call last):
#   File "my_app2.py", line 2, in <module>
#     import dash
#   File "/Users/Pablo/anaconda3/lib/python3.6/site-packages/dash/__init__.py", line 1, in <module>
#     from .dash import Dash  # noqa: F401
#   File "/Users/Pablo/anaconda3/lib/python3.6/site-packages/dash/dash.py", line 18, in <module>
#     import plotly
#   File "/Users/Pablo/anaconda3/lib/python3.6/site-packages/plotly/__init__.py", line 31, in <module>
#     from plotly import (plotly, dashboard_objs, graph_objs, grid_objs, tools,
#   File "/Users/Pablo/anaconda3/lib/python3.6/site-packages/plotly/plotly/__init__.py", line 10, in <module>
#     from . plotly import (
#   File "/Users/Pablo/anaconda3/lib/python3.6/site-packages/plotly/plotly/plotly.py", line 35, in <module>
#     from plotly.graph_objs import Scatter
#   File "/Users/Pablo/anaconda3/lib/python3.6/site-packages/plotly/graph_objs/__init__.py", line 79, in <module>
#     import ipywidgets
#   File "/Users/Pablo/anaconda3/lib/python3.6/site-packages/ipywidgets/__init__.py", line 25, in <module>
#     from .widgets import *
#   File "/Users/Pablo/anaconda3/lib/python3.6/site-packages/ipywidgets/widgets/__init__.py", line 4, in <module>
#     from .widget import Widget, CallbackDispatcher, register, widget_serialization
#   File "/Users/Pablo/anaconda3/lib/python3.6/site-packages/ipywidgets/widgets/widget.py", line 13, in <module>
#     from ipykernel.comm import Comm
#   File "/Users/Pablo/anaconda3/lib/python3.6/site-packages/ipykernel/__init__.py", line 2, in <module>
#     from .connect import *
#   File "/Users/Pablo/anaconda3/lib/python3.6/site-packages/ipykernel/connect.py", line 18, in <module>
#     import jupyter_client
#   File "/Users/Pablo/anaconda3/lib/python3.6/site-packages/jupyter_client/__init__.py", line 4, in <module>
#     from .connect import *
#   File "/Users/Pablo/anaconda3/lib/python3.6/site-packages/jupyter_client/connect.py", line 23, in <module>
#     import zmq
#   File "<frozen importlib._bootstrap>", line 971, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 955, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 665, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 674, in exec_module
#   File "<frozen importlib._bootstrap_external>", line 764, in get_code
#   File "<frozen importlib._bootstrap_external>", line 832, in get_data
# KeyboardInterrupt

# %%
# %%writefile my_app3.py
#Dash simple example
import pandas as pd
import dash
import dash_core_components as dcc
import dash_html_components as html
import plotly.graph_objs as go
from plotly import tools

df = pd.read_csv("DadesSabadell/residus.csv",sep=';')
df.sort_values(by="Anyo",inplace = True)

materials = list(df.NomMaterial.unique())
materials.remove("Resta")

pd.pivot_table(df,columns="Anyo", index = "NomMaterial", values="Quantitat")

minim = 0
maxim = 1000
pas = 100

app = dash.Dash()
app.css.append_css({"external_url": "https://codepen.io/chriddyp/pen/bWLwgP.css"})

app.layout = html.Div([html.Div([dcc.Graph(id='residus_graph')],
                                style={'height':'80%','padding': '0px 20px 20px 20px'}),
                                html.Div([html.H5("Materials amb mitjana de tones per any més grans que:"),
                                    dcc.Slider(id='avg-tones',step = pas,min=minim,max=maxim,value=maxim/2,       
                                            marks={ str(tones): {'label':str(tones)} for tones in range(minim,maxim+pas,pas)})],
                       style={'margin':'auto','height':'20%','width': '70%', 'padding': '0px 0px 40px 40px',"display":'inline_block'})])

@app.callback(
    dash.dependencies.Output('residus_graph', 'figure'),
    [dash.dependencies.Input('avg-tones', 'value')])

def update_figure(avg_tones):
    fig = tools.make_subplots(rows=2, cols=1,shared_xaxes=True, vertical_spacing=0.001)
    traces = []
    
    filtered= df[df['NomMaterial'] =="Resta"]
    trace_Resta = go.Scatter(
                            x=filtered['Anyo'],y=filtered['Quantitat'],text="Resta",
                            mode='lines+markers',
                            opacity=0.7,
                            marker={
                                'size': 15,
                                'line': {'width': 0.5, 'color': 'white'}
                            },
                            name="Resta"
                        )  
    
    filtered = df[df['NomMaterial'].isin(materials)].groupby("Anyo").sum()
    trace_Total= go.Scatter(                      
                            x=filtered.index,y=filtered['Quantitat'],text="Total Materials",
                            mode='lines+markers',
                            opacity=0.7,
                            marker={
                                'size': 15,
                                'line': {'width': 0.5, 'color': 'white'}
                            },
                            name="Total Materials",
                            
                        )   
    
    fig.append_trace(trace_Resta, 1, 1)
    fig.append_trace(trace_Total, 1, 1)
    
    for i in materials :
        filtered= df[df['NomMaterial'] == i]
        y=filtered['Quantitat']
        if (y.mean()>avg_tones) :
            x=filtered['Anyo']
            traces.append(go.Scatter(x=x,y=y,text=i,mode='markers',opacity=0.7,
                                marker={
                                    'size': 15,
                                    'line': {'width': 0.5, 'color': 'white'}
                                }, name=i[0:30])) 
    for trace in traces:
        fig.append_trace(trace, 2, 1)


    fig['layout'].update(height=600,title="Residus a Sabadell", margin={'l': 50, 'b': 40, 't': 40, 'r': 50},
              yaxis1={"title":"Totals"}, yaxis2={"title":"Materials"},hovermode="closest")
    return fig


if __name__ == '__main__':
    app.run_server()
# Out:
# Writing my_app3.py

# %%
# !python my_app3.py
# Out:
#  * Running on http://127.0.0.1:8050/ (Press CTRL+C to quit)
# 127.0.0.1 - - [29/Jan/2019 19:34:27] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jan/2019 19:34:30] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jan/2019 19:34:30] "GET /_dash-dependencies HTTP/1.1" 200 -
# This is the format of your plot grid:
# [ (1,1) x1,y1 ]
# [ (2,1) x1,y2 ]
#
# 127.0.0.1 - - [29/Jan/2019 19:34:37] "POST /_dash-update-component HTTP/1.1" 200 -
# This is the format of your plot grid:
# [ (1,1) x1,y1 ]
# [ (2,1) x1,y2 ]
#
# 127.0.0.1 - - [29/Jan/2019 19:34:38] "POST /_dash-update-component HTTP/1.1" 200 -
# This is the format of your plot grid:
# [ (1,1) x1,y1 ]
# [ (2,1) x1,y2 ]
#
# 127.0.0.1 - - [29/Jan/2019 19:34:42] "POST /_dash-update-component HTTP/1.1" 200 -
# ^C

# %% [markdown]
# # Open Data Barcelona
#
# **EXERCICE**
#
# Using information of 2017's births in Barcelona Districts that you can find at [Open Data Barcelona](http://opendata-ajuntament.barcelona.cat/en/) that you can download [here](http://opendata-ajuntament.barcelona.cat/data/en/dataset/est-demo-naixements-sexe), try to obtain a fancy plot showing girls and boys births per different Barcelona District(Slicer is not necessary).
#
# You also can find this the CSV file with this information in `DadesBarcelona/2017_naixements_sexe.csv`

# %%
import pandas as pd

df = pd.read_csv("DadesBarcelona/2017_naixements_sexe.csv",sep=',')

df.head(20)
# Out:
#      Any  Codi_Districte   Nom_Districte  Codi_Barri  \
# 0   2017               1    Ciutat Vella           1
# 1   2017               1    Ciutat Vella           2
# 2   2017               1    Ciutat Vella           3
# 3   2017               1    Ciutat Vella           4
# 4   2017               2        Eixample           5
# 5   2017               2        Eixample           6
# 6   2017               2        Eixample           7
# 7   2017               2        Eixample           8
# 8   2017               2        Eixample           9
# 9   2017               2        Eixample          10
# 10  2017               3  Sants-Montjuïc          11
# 11  2017               3  Sants-Montjuïc          12
# 12  2017               3  Sants-Montjuïc          13
# 13  2017               3  Sants-Montjuïc          14
# 14  2017               3  Sants-Montjuïc          15
# 15  2017               3  Sants-Montjuïc          16
# 16  2017               3  Sants-Montjuïc          17
# 17  2017               3  Sants-Montjuïc          18
# 18  2017               4       Les Corts          19
# 19  2017               4       Les Corts          20
#
#                                 Nom_Barri  Sexe  Nombre
# 0                                el Raval  Nens     283
# 1                          el Barri Gòtic  Nens      56
# 2                          la Barceloneta  Nens      51
# 3   Sant Pere, Santa Caterina i la Ribera  Nens      90
# 4                           el Fort Pienc  Nens     117
# 5                      la Sagrada Família  Nens     207
# 6                  la Dreta de l'Eixample  Nens     185
# 7         l'Antiga Esquerra de l'Eixample  Nens     176
# 8          la Nova Esquerra de l'Eixample  Nens     218
# 9                             Sant Antoni  Nens     172
# 10                           el Poble Sec  Nens     156
# 11             la Marina del Prat Vermell  Nens       4
# 12                      la Marina de Port  Nens     119
# 13                  la Font de la Guatlla  Nens      42
# 14                            Hostafrancs  Nens      78
# 15                             la Bordeta  Nens      81
# 16                          Sants - Badal  Nens     108
# 17                                  Sants  Nens     155
# 18                              les Corts  Nens     199
# 19             la Maternitat i Sant Ramon  Nens     101

# %%
pd.pivot_table(df, columns="Sexe", index = "Nom_Districte", values="Nombre",  aggfunc='sum')
# Out:
# Sexe                 Nenes  Nens
# Nom_Districte
# Ciutat Vella           412   480
# Eixample               992  1075
# Gràcia                 513   544
# Horta-Guinardó         671   656
# Les Corts              312   332
# Nou Barris             734   742
# Sant Andreu            604   660
# Sant Martí             943  1096
# Sants-Montjuïc         744   743
# Sarrià-Sant Gervasi    623   650

# %%
# %%writefile my_exercice.py
#Dash exercice
import pandas as pd
import dash
import dash_core_components as dcc
import dash_html_components as html
import plotly.graph_objs as go
from plotly import tools
import numpy as np

df = pd.read_csv("DadesBarcelona/2017_naixements_sexe.csv",sep=',')
pv = pd.pivot_table(df, columns="Sexe", index = "Nom_Districte", values="Nombre",  aggfunc='sum')

app = dash.Dash()
app.css.append_css({"external_url": "https://codepen.io/chriddyp/pen/bWLwgP.css"})

app.layout = html.Div([html.Div(
    [dcc.Graph(id='birth_bcn',figure = {
                                    'data':[
                                        {'x': pv.index, 'y': pv['Nenes'], 'type': 'bar', 'name': 'Nenes'},
                                        {'x': pv.index, 'y': pv['Nens'], 'type': 'bar', 'name': 'Nens'},
                                        {'x': pv.index, 'y': pv['Nenes'], 'type': 'lines+markers', 'name': 'Nenes'},
                                        {'x': pv.index, 'y': pv['Nens'], 'type': 'lines+markers', 'name': 'Nens'},
                                        ],
                                        'layout':{
                                            'title' : 'Niñas y niños nacidos en Barcelona por distrito'
                                                }
                                      } )
                                ],
                                style={'height':'80%','padding': '0px 20px 20px 20px'},
                                
                               )])




if __name__ == '__main__':
    app.run_server(debug=True)


if __name__ == '__main__':
    app.run_server()
# Out:
# Overwriting my_exercice.py

# %%
# !python my_exercice.py
# Out:
# Running on http://127.0.0.1:8050/
# Debugger PIN: 357-138-377
# Running on http://127.0.0.1:8050/
# Debugger PIN: 635-344-027
# ^C
# Traceback (most recent call last):
#   File "my_exercice.py", line 41, in <module>
#     app.run_server()
#   File "/Users/Pablo/anaconda3/lib/python3.6/site-packages/dash/dash.py", line 1288, in run_server
#     **flask_run_options)
#   File "/Users/Pablo/anaconda3/lib/python3.6/site-packages/flask/app.py", line 841, in run
#     run_simple(host, port, self, **options)
#   File "/Users/Pablo/anaconda3/lib/python3.6/site-packages/werkzeug/serving.py", line 814, in run_simple
#     inner()
#   File "/Users/Pablo/anaconda3/lib/python3.6/site-packages/werkzeug/serving.py", line 774, in inner
#     fd=fd)
#   File "/Users/Pablo/anaconda3/lib/python3.6/site-packages/werkzeug/serving.py", line 666, in make_server
#     passthrough_errors, ssl_context, fd=fd)
#   File "/Users/Pablo/anaconda3/lib/python3.6/site-packages/werkzeug/serving.py", line 574, in __init__
#     socket.SOCK_STREAM)
#   File "/Users/Pablo/anaconda3/lib/python3.6/socket.py", line 460, in fromfd
#     nfd = dup(fd)
# OSError: [Errno 9] Bad file descriptor
